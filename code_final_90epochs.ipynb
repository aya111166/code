# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow.keras import models , layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D,BatchNormalization ,Flatten ,Reshape  ,RepeatVector ,Concatenate
from tensorflow.keras.layers import  Conv2D,LSTM ,Bidirectional  ,Input,Embedding  ,GlobalMaxPool1D ,TimeDistributed

from tensorflow.keras.layers import Activation,MaxPooling2D,AveragePooling3D,GlobalMaxPool2D,AveragePooling2D
from tensorflow.keras.layers import MaxPooling3D,GlobalAveragePooling3D,GlobalMaxPool3D,Conv3D

from sklearn.model_selection import train_test_split ,StratifiedKFold ,KFold ,RepeatedKFold
from sklearn import preprocessing

from tensorflow.keras import Model 

from keras.utils import np_utils

from sklearn.cluster import KMeans
from sklearn import cluster


import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import os

import pylab as pl

from scipy import interp
from itertools import cycle
import matplotlib.patches as patches


from sklearn.metrics import accuracy_score ,roc_curve, auc ,roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


def invert_permutation(p):
    '''The argument p is assumed to be some permutation of 0, 1, ..., len(p)-1. 
    Returns an array s, where s[i] gives the index of i in p.
    '''
    s = np.empty(p.size, p.dtype)
    s[p] = np.arange(p.size)
    return s


from tensorflow.keras import backend as K
def pearson_r(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.sum(xm * ym)
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = K.sqrt(x_square_sum * y_square_sum)
    r = r_num / r_den
    return K.mean(r)



import os 
from PIL import Image
import numpy as np
from numpy import *   

from matplotlib import pyplot as plt
from IPython import display


from patchify import patchify, unpatchify


import matplotlib.pyplot as plt
# %pylab inline
# %load_ext tensorboard
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Aya\anaconda3\envs\tf-gpu\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['display']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
def cancer_NC(splits , epochs,batch_size):


    mat_sc= scipy.io.loadmat('cancer_img_p')
    cancer_img_p = mat_sc['cancer_img_p']

    mat_sc= scipy.io.loadmat('normal_img_p')
    normal_img_p = mat_sc['normal_img_p']

    labels_cancer_ = np.ones((cancer_img_p.shape[0],1))
    labels_normal_ = np.zeros((normal_img_p.shape[0],1))



    x_cancer_NC_ = np.concatenate((cancer_img_p, normal_img_p), axis=0) 
    y_cancer_NC_ = np.concatenate((labels_cancer_, labels_normal_), axis=0) 

    x_cancer_NC_=np.asarray(tf.expand_dims(x_cancer_NC_, axis=-1))





    x_cancer_NC_1 = x_cancer_NC_[:,0,0]
    x_cancer_NC_2 = x_cancer_NC_[:,1,0]
    x_cancer_NC_3 = x_cancer_NC_[:,2,0]
    x_cancer_NC_4 = x_cancer_NC_[:,3,0]
    x_cancer_NC_5 = x_cancer_NC_[:,4,0]
    x_cancer_NC_6 = x_cancer_NC_[:,5,0]

    x_cancer_NC_7 = x_cancer_NC_[:,6,0]
    x_cancer_NC_8 = x_cancer_NC_[:,7,0]
    x_cancer_NC_9 = x_cancer_NC_[:,8,0]
    x_cancer_NC_10 = x_cancer_NC_[:,9,0]
    x_cancer_NC_11 = x_cancer_NC_[:,10,0]




    n = x_cancer_NC_1.shape[0]
    permutation = list(np.random.permutation(n))
    x_cancer_NC_1 = x_cancer_NC_1[permutation]
    x_cancer_NC_2 = x_cancer_NC_2[permutation]
    x_cancer_NC_3 = x_cancer_NC_3[permutation]
    x_cancer_NC_4 = x_cancer_NC_4[permutation]
    x_cancer_NC_5 = x_cancer_NC_5[permutation]
    x_cancer_NC_6 = x_cancer_NC_6[permutation]


    x_cancer_NC_7 = x_cancer_NC_7[permutation]
    x_cancer_NC_8 = x_cancer_NC_8[permutation]
    x_cancer_NC_9 = x_cancer_NC_9[permutation]
    x_cancer_NC_10 = x_cancer_NC_10[permutation]
    x_cancer_NC_11 = x_cancer_NC_11[permutation]




    y_cancer_NC_ = y_cancer_NC_[permutation]

    permutation_xray = np.asarray(permutation)




    input_1 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_1')



    conv_1 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)



    conv_1 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = AveragePooling2D()(conv_1)












    input_2 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_2')

    conv_2 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)



    conv_2 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = AveragePooling2D()(conv_2)







    input_3= tf.keras.layers.Input(shape=[256, 256,1], name='main_input_3')

    conv_3 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)



    conv_3 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = AveragePooling2D()(conv_3)





    input_4= tf.keras.layers.Input(shape=[256, 256,1], name='main_input_4')


    conv_4 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)



    conv_4 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = AveragePooling2D()(conv_4)







    input_5 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_5')

    conv_5 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)



    conv_5 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = AveragePooling2D()(conv_5)





    input_6 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_6')


    conv_6 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)



    conv_6 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = AveragePooling2D()(conv_6)




    input_7 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_7')



    conv_7 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)



    conv_7 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = AveragePooling2D()(conv_7)







    input_8 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_8')



    conv_8 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)



    conv_8 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = AveragePooling2D()(conv_8)






    input_9 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_9')



    conv_9 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)



    conv_9 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = AveragePooling2D()(conv_9)





    input_10 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_10')



    conv_10 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)



    conv_10 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = AveragePooling2D()(conv_10)






    input_11 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_11')



    conv_11 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)



    conv_11 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = AveragePooling2D()(conv_11)











    x = Concatenate(axis =-1)([conv_1,conv_2])
    x = Concatenate(axis =-1)([x,conv_3])
    x = Concatenate(axis =-1)([x,conv_4])
    x = Concatenate(axis =-1)([x,conv_5])
    x = Concatenate(axis =-1)([x,conv_6])

    x = Concatenate(axis =-1)([x,conv_7])
    x = Concatenate(axis =-1)([x,conv_8])
    x = Concatenate(axis =-1)([x,conv_9])
    x = Concatenate(axis =-1)([x,conv_10])
    x = Concatenate(axis =-1)([x,conv_11])






    x_4 = tf.keras.layers.Flatten()(x)
    print(x_4.shape)

    x_4 = tf.keras.layers.Dense(64,  name="layer_dense")(x_4)

    x_4 = tf.keras.layers.Dense(2, activation='softmax' , name="layer_x")(x_4)


    adam = tf.keras.optimizers.Adam( lr=1e-4)

    model = tf.keras.Model(inputs= [input_1,input_2,input_3,input_4,input_5,input_6,
                                   input_7,input_8,input_9,input_10,input_11], outputs= x_4)

    model.compile(optimizer= adam , 
                      loss= { 'layer_x':'binary_crossentropy'},
                      metrics={ 'layer_x':'accuracy'})




    kfold = StratifiedKFold(n_splits=splits,  random_state=np.random.seed(0))


    accuracy_train_x_=[]
    accuracy_test_x_=[] 

    mean_tpr = 0.0
    mean_fpr = np.linspace(0, 1, 100)
    all_tpr = []


    accuracy_tr_all=[]
    accuracy_te_all=[]

    confusion_matrix_1_last =[]
 

    count = 1
    for train_index, test_index in kfold.split(x_cancer_NC_1, y_cancer_NC_):
        print(count)
        count = count+1

        x_train_1, x_test_1 = x_cancer_NC_1[train_index], x_cancer_NC_1[test_index]
        y_train, y_test = y_cancer_NC_[train_index], y_cancer_NC_[test_index]
        
        

        x_train_2, x_test_2 = x_cancer_NC_2[train_index], x_cancer_NC_2[test_index]
        x_train_3, x_test_3 = x_cancer_NC_3[train_index], x_cancer_NC_3[test_index]
        x_train_4, x_test_4 = x_cancer_NC_4[train_index], x_cancer_NC_4[test_index]
        x_train_5, x_test_5 = x_cancer_NC_5[train_index], x_cancer_NC_5[test_index]
        x_train_6, x_test_6 = x_cancer_NC_6[train_index], x_cancer_NC_6[test_index]

        
        x_train_7, x_test_7 = x_cancer_NC_7[train_index], x_cancer_NC_7[test_index]
        x_train_8, x_test_8 = x_cancer_NC_8[train_index], x_cancer_NC_8[test_index]
        x_train_9, x_test_9 = x_cancer_NC_9[train_index], x_cancer_NC_9[test_index]
        x_train_10, x_test_10 = x_cancer_NC_10[train_index], x_cancer_NC_10[test_index]
        x_train_11, x_test_11 = x_cancer_NC_11[train_index], x_cancer_NC_11[test_index]

             

        ## normalization : normalize each feature for norm = 1
        # axis 0 for columns ( features) and axis 1 for rows for this function
        # f.keras.utils.normalize() and also this function make l2 norm according to the chosen axis

        x_train_1 = tf.keras.utils.normalize(x_train_1, axis=1)
        x_train_2 = tf.keras.utils.normalize(x_train_2, axis=1)
        x_train_3 = tf.keras.utils.normalize(x_train_3, axis=1)
        x_train_4 = tf.keras.utils.normalize(x_train_4, axis=1)
        x_train_5 = tf.keras.utils.normalize(x_train_5, axis=1)
        x_train_6 = tf.keras.utils.normalize(x_train_6, axis=1)
        
        x_train_7 = tf.keras.utils.normalize(x_train_7, axis=1)
        x_train_8 = tf.keras.utils.normalize(x_train_8, axis=1)
        x_train_9 = tf.keras.utils.normalize(x_train_9, axis=1)
        x_train_10 = tf.keras.utils.normalize(x_train_10, axis=1)
        x_train_11 = tf.keras.utils.normalize(x_train_11, axis=1)
        
        
       
        x_test_1 = tf.keras.utils.normalize(x_test_1, axis=1)
        x_test_2 = tf.keras.utils.normalize(x_test_2, axis=1)
        x_test_3 = tf.keras.utils.normalize(x_test_3, axis=1)
        x_test_4 = tf.keras.utils.normalize(x_test_4, axis=1)
        x_test_5 = tf.keras.utils.normalize(x_test_5, axis=1)
        x_test_6 = tf.keras.utils.normalize(x_test_6, axis=1)
        
        x_test_7 = tf.keras.utils.normalize(x_test_7, axis=1)
        x_test_8 = tf.keras.utils.normalize(x_test_8, axis=1)
        x_test_9 = tf.keras.utils.normalize(x_test_9, axis=1)
        x_test_10 = tf.keras.utils.normalize(x_test_10, axis=1)
        x_test_11 = tf.keras.utils.normalize(x_test_11, axis=1)
        
        
       
        ## two output for classification
        
    
        ## two output for classification

        uniques_y_test, ids_y_test = np.unique(y_test, return_inverse=True)   
        
        
        y_train = np_utils.to_categorical(y_train, num_classes=2)
        y_test  =  np_utils.to_categorical(y_test, num_classes=2)


        history = model.fit([x_train_1,x_train_2,x_train_3,x_train_4,x_train_5,x_train_6,
                            x_train_7,x_train_8,x_train_9,x_train_10,x_train_11], y_train, 
                            epochs=epochs, batch_size=batch_size , 
                            validation_data=( [x_test_1,x_test_2,x_test_3,x_test_4,x_test_5,x_test_6,
                                              x_test_7,x_test_8,x_test_9,x_test_10,x_test_11] , y_test))

        

        
        
        
        print(history.history.keys())
        a,accuracy_train_x = model.evaluate([x_train_1,x_train_2,x_train_3,x_train_4,x_train_5,x_train_6,
                                            x_train_7,x_train_8,x_train_9,x_train_10,x_train_11],y_train)

        a, accuracy_test_x = model.evaluate([x_test_1,x_test_2,x_test_3,x_test_4,x_test_5,x_test_6,
                                            x_test_7,x_test_8,x_test_9,x_test_10,x_test_11],y_test)

        accuracy_train_x_.append(accuracy_train_x)

        accuracy_test_x_.append(accuracy_test_x)   
   



        # classification paramaters


        yhat_probs = model.predict([x_test_1,x_test_2,x_test_3,x_test_4,x_test_5,x_test_6,
                                                      x_test_7,x_test_8,x_test_9,x_test_10,x_test_11])


        yhat_classes =yhat_probs>0.5
        yhat_classes_1 =  1*yhat_classes 


        # confusion matrix
        y_test_con = uniques_y_test[y_test.argmax(1)]
        yhat_classes_1_con = uniques_y_test[yhat_classes_1.argmax(1)]

        confusion_matrix_1_last.append(confusion_matrix(y_test_con, yhat_classes_1_con,labels=[0, 1]))


        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve( y_cancer_NC_[test_index], yhat_classes_1_con)  
        mean_tpr += interp(mean_fpr, fpr, tpr)
        mean_tpr[0] = 0.0
        roc_auc = auc(fpr, tpr)
        

    mean_tpr /= splits
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)

    

    
    
    return    accuracy_train_x_,accuracy_test_x_,confusion_matrix_1_last,mean_fpr,mean_tpr,mean_auc

# %%
iteration = 10
splits = 10
epochs= 90
batch_size=32


    
total_accuracy_tr =  np.zeros( (iteration,splits), dtype=np.float32) 
total_accuracy_te =  np.zeros( (iteration,splits), dtype=np.float32) 
total_confusion_matrix_1_last =  np.zeros( (iteration,splits,2,2), dtype=np.float32) 


mean_fpr_t =  np.zeros( (iteration,100), dtype=np.float32) 
mean_tpr_t =  np.zeros( (iteration,100), dtype=np.float32) 
mean_auc_t =  np.zeros( (iteration,1), dtype=np.float32) 




for i in list(range(iteration)):
    accuracy_tr_all,accuracy_te_all, confusion_matrix_1_last,mean_fpr,mean_tpr,mean_auc  = cancer_NC(splits , epochs,batch_size)


    
    total_accuracy_tr[i , ] =   accuracy_tr_all       
    total_accuracy_te[i , ] =   accuracy_te_all       
   
    total_confusion_matrix_1_last[i , ] =   confusion_matrix_1_last       


    
    mean_fpr_t[i , ]  =  mean_fpr      
    mean_tpr_t[i , ]  =  mean_tpr
    mean_auc_t[i , ]  =  mean_auc
# Out:
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 90112)
# 1
# C:\Users\Aya\anaconda3\envs\tf-gpu\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/90
# 7/7 [==============================] - 193s 19s/step - loss: 1.4084 - accuracy: 0.5405 - val_loss: 0.7270 - val_accuracy: 0.4000
# Epoch 2/90
# 7/7 [==============================] - 96s 14s/step - loss: 1.0546 - accuracy: 0.6486 - val_loss: 0.7086 - val_accuracy: 0.4000
# Epoch 3/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.8517 - accuracy: 0.6757 - val_loss: 0.7532 - val_accuracy: 0.4000
# Epoch 4/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.6367 - accuracy: 0.7477 - val_loss: 0.8626 - val_accuracy: 0.4000
# Epoch 5/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.6061 - accuracy: 0.7477 - val_loss: 0.7942 - val_accuracy: 0.4000
# Epoch 6/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.4828 - accuracy: 0.8468 - val_loss: 0.7148 - val_accuracy: 0.4000
# Epoch 7/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.4872 - accuracy: 0.8153 - val_loss: 0.7111 - val_accuracy: 0.4000
# Epoch 8/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.5108 - accuracy: 0.8018 - val_loss: 0.7465 - val_accuracy: 0.4000
# Epoch 9/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.4543 - accuracy: 0.8018 - val_loss: 0.7626 - val_accuracy: 0.4000
# Epoch 10/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.5536 - accuracy: 0.8018 - val_loss: 1.3182 - val_accuracy: 0.4000
# Epoch 11/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.5042 - accuracy: 0.8198 - val_loss: 1.0112 - val_accuracy: 0.4000
# Epoch 12/90
# 7/7 [==============================] - 101s 15s/step - loss: 0.4070 - accuracy: 0.8604 - val_loss: 0.7731 - val_accuracy: 0.6000
# Epoch 13/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.3975 - accuracy: 0.8333 - val_loss: 0.6985 - val_accuracy: 0.6000
# Epoch 14/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.3762 - accuracy: 0.8604 - val_loss: 0.8595 - val_accuracy: 0.4000
# Epoch 15/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.3549 - accuracy: 0.8739 - val_loss: 0.7447 - val_accuracy: 0.4000
# Epoch 16/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.3574 - accuracy: 0.8694 - val_loss: 0.7462 - val_accuracy: 0.6000
# Epoch 17/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.3815 - accuracy: 0.8288 - val_loss: 0.6804 - val_accuracy: 0.6000
# Epoch 18/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.3699 - accuracy: 0.8468 - val_loss: 0.7528 - val_accuracy: 0.6000
# Epoch 19/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.3095 - accuracy: 0.8829 - val_loss: 0.9788 - val_accuracy: 0.6000
# Epoch 20/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.3724 - accuracy: 0.8784 - val_loss: 0.6732 - val_accuracy: 0.6000
# Epoch 21/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.3208 - accuracy: 0.8874 - val_loss: 0.8584 - val_accuracy: 0.6000
# Epoch 22/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.2497 - accuracy: 0.8919 - val_loss: 0.7121 - val_accuracy: 0.6000
# Epoch 23/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.3315 - accuracy: 0.9009 - val_loss: 0.7113 - val_accuracy: 0.6000
# Epoch 24/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.2899 - accuracy: 0.9099 - val_loss: 0.7053 - val_accuracy: 0.6000
# Epoch 25/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.2757 - accuracy: 0.9234 - val_loss: 0.6941 - val_accuracy: 0.6800
# Epoch 26/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.2787 - accuracy: 0.9189 - val_loss: 0.8579 - val_accuracy: 0.4000
# Epoch 27/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.2749 - accuracy: 0.8874 - val_loss: 0.7514 - val_accuracy: 0.6000
# Epoch 28/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.2288 - accuracy: 0.9279 - val_loss: 0.8504 - val_accuracy: 0.6000
# Epoch 29/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.2331 - accuracy: 0.9324 - val_loss: 1.5130 - val_accuracy: 0.6000
# Epoch 30/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.2334 - accuracy: 0.9279 - val_loss: 0.7753 - val_accuracy: 0.6000
# Epoch 31/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.2471 - accuracy: 0.9144 - val_loss: 0.6788 - val_accuracy: 0.6000
# Epoch 32/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.2079 - accuracy: 0.9279 - val_loss: 0.8783 - val_accuracy: 0.6000
# Epoch 33/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.2073 - accuracy: 0.9324 - val_loss: 1.0182 - val_accuracy: 0.6000
# Epoch 34/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1906 - accuracy: 0.9414 - val_loss: 1.3200 - val_accuracy: 0.4000
# Epoch 35/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.2568 - accuracy: 0.9189 - val_loss: 1.1543 - val_accuracy: 0.6000
# Epoch 36/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.2581 - accuracy: 0.9189 - val_loss: 1.0239 - val_accuracy: 0.6000
# Epoch 37/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1972 - accuracy: 0.9189 - val_loss: 1.2483 - val_accuracy: 0.6000
# Epoch 38/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.1979 - accuracy: 0.9279 - val_loss: 1.4937 - val_accuracy: 0.4000
# Epoch 39/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.2384 - accuracy: 0.9414 - val_loss: 1.4194 - val_accuracy: 0.6000
# Epoch 40/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.1428 - accuracy: 0.9505 - val_loss: 1.6620 - val_accuracy: 0.6000
# Epoch 41/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1837 - accuracy: 0.9414 - val_loss: 1.7292 - val_accuracy: 0.6000
# Epoch 42/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1736 - accuracy: 0.9505 - val_loss: 1.4511 - val_accuracy: 0.6000
# Epoch 43/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1094 - accuracy: 0.9730 - val_loss: 1.1284 - val_accuracy: 0.6000
# Epoch 44/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.1409 - accuracy: 0.9459 - val_loss: 0.8628 - val_accuracy: 0.6000
# Epoch 45/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.1370 - accuracy: 0.9730 - val_loss: 0.6669 - val_accuracy: 0.6000
# Epoch 46/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1047 - accuracy: 0.9640 - val_loss: 1.5433 - val_accuracy: 0.6000
# Epoch 47/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1154 - accuracy: 0.9775 - val_loss: 2.0634 - val_accuracy: 0.6000
# Epoch 48/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1336 - accuracy: 0.9685 - val_loss: 1.6408 - val_accuracy: 0.6000
# Epoch 49/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1507 - accuracy: 0.9414 - val_loss: 1.0190 - val_accuracy: 0.6000
# Epoch 50/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.1344 - accuracy: 0.9550 - val_loss: 0.9532 - val_accuracy: 0.6000
# Epoch 51/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0971 - accuracy: 0.9820 - val_loss: 0.7252 - val_accuracy: 0.6000
# Epoch 52/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1011 - accuracy: 0.9685 - val_loss: 0.9505 - val_accuracy: 0.6000
# Epoch 53/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0734 - accuracy: 0.9865 - val_loss: 1.1594 - val_accuracy: 0.6000
# Epoch 54/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.0965 - accuracy: 0.9865 - val_loss: 1.0833 - val_accuracy: 0.6000
# Epoch 55/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1068 - accuracy: 0.9730 - val_loss: 0.9635 - val_accuracy: 0.6000
# Epoch 56/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1183 - accuracy: 0.9640 - val_loss: 1.5523 - val_accuracy: 0.6000
# Epoch 57/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1488 - accuracy: 0.9459 - val_loss: 1.2149 - val_accuracy: 0.6000
# Epoch 58/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0958 - accuracy: 0.9685 - val_loss: 2.0856 - val_accuracy: 0.6000
# Epoch 59/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0886 - accuracy: 0.9775 - val_loss: 1.5889 - val_accuracy: 0.6000
# Epoch 60/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.1381 - accuracy: 0.9550 - val_loss: 2.9025 - val_accuracy: 0.6000
# Epoch 61/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1462 - accuracy: 0.9414 - val_loss: 2.5788 - val_accuracy: 0.6000
# Epoch 62/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0925 - accuracy: 0.9775 - val_loss: 2.4462 - val_accuracy: 0.6000
# Epoch 63/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0926 - accuracy: 0.9775 - val_loss: 3.2575 - val_accuracy: 0.6000
# Epoch 64/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1103 - accuracy: 0.9550 - val_loss: 2.0302 - val_accuracy: 0.6000
# Epoch 65/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.1029 - accuracy: 0.9685 - val_loss: 1.6012 - val_accuracy: 0.6000
# Epoch 66/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.1550 - accuracy: 0.9369 - val_loss: 2.6835 - val_accuracy: 0.6000
# Epoch 67/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1198 - accuracy: 0.9595 - val_loss: 3.0444 - val_accuracy: 0.6000
# Epoch 68/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1708 - accuracy: 0.9505 - val_loss: 4.6297 - val_accuracy: 0.6000
# Epoch 69/90
# 7/7 [==============================] - 100s 13s/step - loss: 0.0566 - accuracy: 0.9820 - val_loss: 2.3508 - val_accuracy: 0.6000
# Epoch 70/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1497 - accuracy: 0.9505 - val_loss: 2.3079 - val_accuracy: 0.6000
# Epoch 71/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0592 - accuracy: 0.9865 - val_loss: 1.9927 - val_accuracy: 0.6000
# Epoch 72/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.1230 - accuracy: 0.9595 - val_loss: 1.7675 - val_accuracy: 0.6000
# Epoch 73/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0628 - accuracy: 0.9910 - val_loss: 2.7132 - val_accuracy: 0.6000
# Epoch 74/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0705 - accuracy: 0.9775 - val_loss: 3.1394 - val_accuracy: 0.6000
# Epoch 75/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0802 - accuracy: 0.9730 - val_loss: 3.3555 - val_accuracy: 0.6000
# Epoch 76/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0823 - accuracy: 0.9730 - val_loss: 4.1537 - val_accuracy: 0.6000
# Epoch 77/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0576 - accuracy: 0.9820 - val_loss: 3.4234 - val_accuracy: 0.6000
# Epoch 78/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0665 - accuracy: 0.9775 - val_loss: 3.3716 - val_accuracy: 0.6000
# Epoch 79/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0715 - accuracy: 0.9730 - val_loss: 3.8812 - val_accuracy: 0.6000
# Epoch 80/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0705 - accuracy: 0.9910 - val_loss: 2.4334 - val_accuracy: 0.6000
# Epoch 81/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.1046 - accuracy: 0.9685 - val_loss: 1.8251 - val_accuracy: 0.6000
# Epoch 82/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0740 - accuracy: 0.9730 - val_loss: 2.0429 - val_accuracy: 0.6000
# Epoch 83/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0410 - accuracy: 0.9910 - val_loss: 1.3489 - val_accuracy: 0.5600
# Epoch 84/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0373 - accuracy: 0.9865 - val_loss: 2.1102 - val_accuracy: 0.6000
# Epoch 85/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 2.1232 - val_accuracy: 0.6000
# Epoch 86/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0898 - accuracy: 0.9730 - val_loss: 1.7009 - val_accuracy: 0.6000
# Epoch 87/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0354 - accuracy: 0.9955 - val_loss: 1.7011 - val_accuracy: 0.6000
# Epoch 88/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0724 - accuracy: 0.9820 - val_loss: 1.3088 - val_accuracy: 0.4800
# Epoch 89/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0347 - accuracy: 0.9910 - val_loss: 1.5160 - val_accuracy: 0.5200
# Epoch 90/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.0464 - accuracy: 0.9955 - val_loss: 1.4111 - val_accuracy: 0.4800
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 12s 2s/step - loss: 0.8640 - accuracy: 0.7432
# 1/1 [==============================] - 1s 1s/step - loss: 1.4111 - accuracy: 0.4800
# 2
# Epoch 1/90
# 7/7 [==============================] - 113s 14s/step - loss: 0.2991 - accuracy: 0.9324 - val_loss: 1.2043 - val_accuracy: 0.6000
# Epoch 2/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.2165 - accuracy: 0.9459 - val_loss: 0.8999 - val_accuracy: 0.6400
# Epoch 3/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.2274 - accuracy: 0.9369 - val_loss: 1.4235 - val_accuracy: 0.6800
# Epoch 4/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.1314 - accuracy: 0.9730 - val_loss: 1.0900 - val_accuracy: 0.7200
# Epoch 5/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1257 - accuracy: 0.9685 - val_loss: 0.9392 - val_accuracy: 0.7200
# Epoch 6/90
# 7/7 [==============================] - 101s 15s/step - loss: 0.0898 - accuracy: 0.9820 - val_loss: 0.8699 - val_accuracy: 0.6800
# Epoch 7/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0734 - accuracy: 0.9775 - val_loss: 1.2319 - val_accuracy: 0.6400
# Epoch 8/90
# 7/7 [==============================] - 100s 14s/step - loss: 0.1104 - accuracy: 0.9730 - val_loss: 1.1844 - val_accuracy: 0.6400
# Epoch 9/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0939 - accuracy: 0.9730 - val_loss: 1.2628 - val_accuracy: 0.6400
# Epoch 10/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0625 - accuracy: 0.9820 - val_loss: 1.3696 - val_accuracy: 0.6400
# Epoch 11/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0875 - accuracy: 0.9820 - val_loss: 1.8841 - val_accuracy: 0.6400
# Epoch 12/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0821 - accuracy: 0.9820 - val_loss: 1.5671 - val_accuracy: 0.6800
# Epoch 13/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0825 - accuracy: 0.9730 - val_loss: 2.3190 - val_accuracy: 0.6400
# Epoch 14/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0736 - accuracy: 0.9865 - val_loss: 1.2915 - val_accuracy: 0.6400
# Epoch 15/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0794 - accuracy: 0.9730 - val_loss: 2.0553 - val_accuracy: 0.6800
# Epoch 16/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0627 - accuracy: 0.9775 - val_loss: 1.2990 - val_accuracy: 0.6800
# Epoch 17/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0664 - accuracy: 0.9775 - val_loss: 1.5225 - val_accuracy: 0.6800
# Epoch 18/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0533 - accuracy: 0.9910 - val_loss: 1.9195 - val_accuracy: 0.6800
# Epoch 19/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0635 - accuracy: 0.9865 - val_loss: 1.9663 - val_accuracy: 0.6800
# Epoch 20/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 2.3480 - val_accuracy: 0.6400
# Epoch 21/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0493 - accuracy: 0.9910 - val_loss: 1.1350 - val_accuracy: 0.6400
# Epoch 22/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0536 - accuracy: 0.9865 - val_loss: 1.3221 - val_accuracy: 0.6800
# Epoch 23/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0377 - accuracy: 0.9910 - val_loss: 1.0241 - val_accuracy: 0.7600
# Epoch 24/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0299 - accuracy: 0.9910 - val_loss: 1.3656 - val_accuracy: 0.6800
# Epoch 25/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0702 - accuracy: 0.9775 - val_loss: 1.0260 - val_accuracy: 0.8000
# Epoch 26/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0672 - accuracy: 0.9865 - val_loss: 0.8705 - val_accuracy: 0.6800
# Epoch 27/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0563 - accuracy: 0.9910 - val_loss: 1.2973 - val_accuracy: 0.7600
# Epoch 28/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0872 - accuracy: 0.9820 - val_loss: 0.8794 - val_accuracy: 0.7600
# Epoch 29/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0462 - accuracy: 0.9865 - val_loss: 1.0713 - val_accuracy: 0.7600
# Epoch 30/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0885 - accuracy: 0.9775 - val_loss: 0.8145 - val_accuracy: 0.7600
# Epoch 31/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0404 - accuracy: 0.9865 - val_loss: 0.8693 - val_accuracy: 0.8000
# Epoch 32/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0586 - accuracy: 0.9910 - val_loss: 1.4800 - val_accuracy: 0.7200
# Epoch 33/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0753 - accuracy: 0.9820 - val_loss: 1.0133 - val_accuracy: 0.7600
# Epoch 34/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0290 - accuracy: 0.9955 - val_loss: 0.8094 - val_accuracy: 0.8000
# Epoch 35/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0513 - accuracy: 0.9865 - val_loss: 0.8982 - val_accuracy: 0.8000
# Epoch 36/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0348 - accuracy: 0.9910 - val_loss: 0.7638 - val_accuracy: 0.8000
# Epoch 37/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0362 - accuracy: 0.9910 - val_loss: 0.8078 - val_accuracy: 0.8000
# Epoch 38/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.0062 - val_accuracy: 0.7600
# Epoch 39/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0287 - accuracy: 0.9910 - val_loss: 0.8295 - val_accuracy: 0.7600
# Epoch 40/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0417 - accuracy: 0.9865 - val_loss: 0.7199 - val_accuracy: 0.8000
# Epoch 41/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.8400 - val_accuracy: 0.8400
# Epoch 42/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.9412 - val_accuracy: 0.8400
# Epoch 43/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0254 - accuracy: 0.9955 - val_loss: 0.9421 - val_accuracy: 0.8000
# Epoch 44/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.9068 - val_accuracy: 0.7200
# Epoch 45/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0288 - accuracy: 0.9910 - val_loss: 0.8154 - val_accuracy: 0.8400
# Epoch 46/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0288 - accuracy: 0.9910 - val_loss: 0.8606 - val_accuracy: 0.8400
# Epoch 47/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0317 - accuracy: 0.9955 - val_loss: 0.7622 - val_accuracy: 0.8400
# Epoch 48/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 0.7634 - val_accuracy: 0.8400
# Epoch 49/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0308 - accuracy: 0.9910 - val_loss: 0.9614 - val_accuracy: 0.7600
# Epoch 50/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0259 - accuracy: 0.9910 - val_loss: 0.7609 - val_accuracy: 0.8400
# Epoch 51/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0211 - accuracy: 0.9955 - val_loss: 0.7530 - val_accuracy: 0.8400
# Epoch 52/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0384 - accuracy: 0.9865 - val_loss: 0.9424 - val_accuracy: 0.7200
# Epoch 53/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0329 - accuracy: 0.9955 - val_loss: 0.7070 - val_accuracy: 0.8400
# Epoch 54/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0257 - accuracy: 0.9955 - val_loss: 0.7109 - val_accuracy: 0.8400
# Epoch 55/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.2316 - val_accuracy: 0.7200
# Epoch 56/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0339 - accuracy: 0.9910 - val_loss: 0.9974 - val_accuracy: 0.8000
# Epoch 57/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0562 - accuracy: 0.9820 - val_loss: 1.0399 - val_accuracy: 0.7600
# Epoch 58/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0560 - accuracy: 0.9865 - val_loss: 1.3597 - val_accuracy: 0.7600
# Epoch 59/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0678 - accuracy: 0.9865 - val_loss: 1.1224 - val_accuracy: 0.8000
# Epoch 60/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0190 - accuracy: 0.9955 - val_loss: 1.2067 - val_accuracy: 0.7600
# Epoch 61/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0570 - accuracy: 0.9955 - val_loss: 1.7245 - val_accuracy: 0.7600
# Epoch 62/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 1.1171 - val_accuracy: 0.7600
# Epoch 63/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0212 - accuracy: 0.9865 - val_loss: 1.0080 - val_accuracy: 0.8000
# Epoch 64/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0280 - accuracy: 0.9910 - val_loss: 1.3667 - val_accuracy: 0.7200
# Epoch 65/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0485 - accuracy: 0.9775 - val_loss: 0.9138 - val_accuracy: 0.8400
# Epoch 66/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0243 - accuracy: 0.9955 - val_loss: 1.0708 - val_accuracy: 0.8000
# Epoch 67/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0249 - accuracy: 0.9955 - val_loss: 1.1226 - val_accuracy: 0.8000
# Epoch 68/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.9754 - val_accuracy: 0.8400
# Epoch 69/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.8622 - val_accuracy: 0.8400
# Epoch 70/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.9732 - val_accuracy: 0.7600
# Epoch 71/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.8073 - val_accuracy: 0.8400
# Epoch 72/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8283 - val_accuracy: 0.8400
# Epoch 73/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.8848 - val_accuracy: 0.8400
# Epoch 74/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.8996 - val_accuracy: 0.8400
# Epoch 75/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0413 - accuracy: 0.9820 - val_loss: 0.8635 - val_accuracy: 0.8400
# Epoch 76/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0089 - accuracy: 0.9955 - val_loss: 0.9769 - val_accuracy: 0.8400
# Epoch 77/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0779 - val_accuracy: 0.8400
# Epoch 78/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.2029 - val_accuracy: 0.8000
# Epoch 79/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0369 - accuracy: 0.9865 - val_loss: 1.0207 - val_accuracy: 0.8000
# Epoch 80/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0277 - accuracy: 0.9955 - val_loss: 0.8968 - val_accuracy: 0.8400
# Epoch 81/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.8979 - val_accuracy: 0.8400
# Epoch 82/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 1.0180 - val_accuracy: 0.7600
# Epoch 83/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0198 - accuracy: 0.9910 - val_loss: 1.0216 - val_accuracy: 0.7600
# Epoch 84/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9774 - val_accuracy: 0.8400
# Epoch 85/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0077 - accuracy: 0.9955 - val_loss: 1.1292 - val_accuracy: 0.8000
# Epoch 86/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0362 - accuracy: 0.9910 - val_loss: 1.3541 - val_accuracy: 0.7200
# Epoch 87/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0187 - accuracy: 0.9955 - val_loss: 1.0151 - val_accuracy: 0.8000
# Epoch 88/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.9381 - val_accuracy: 0.8400
# Epoch 89/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0161 - accuracy: 0.9955 - val_loss: 0.8760 - val_accuracy: 0.8400
# Epoch 90/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0261 - accuracy: 0.9910 - val_loss: 0.9134 - val_accuracy: 0.8000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 11s 1s/step - loss: 0.4238 - accuracy: 0.8919
# 1/1 [==============================] - 1s 1s/step - loss: 0.9134 - accuracy: 0.8000
# 3
# Epoch 1/90
# 7/7 [==============================] - 128s 16s/step - loss: 0.0506 - accuracy: 0.9910 - val_loss: 1.8474 - val_accuracy: 0.7600
# Epoch 2/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0292 - accuracy: 0.9955 - val_loss: 1.1307 - val_accuracy: 0.8400
# Epoch 3/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0514 - accuracy: 0.9955 - val_loss: 1.3849 - val_accuracy: 0.8000
# Epoch 4/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0391 - accuracy: 0.9865 - val_loss: 1.3919 - val_accuracy: 0.8000
# Epoch 5/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0327 - accuracy: 0.9955 - val_loss: 0.6979 - val_accuracy: 0.8400
# Epoch 6/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0632 - accuracy: 0.9820 - val_loss: 0.3667 - val_accuracy: 0.8800
# Epoch 7/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0555 - accuracy: 0.9775 - val_loss: 0.7068 - val_accuracy: 0.8000
# Epoch 8/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.6628 - val_accuracy: 0.8000
# Epoch 9/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0371 - accuracy: 0.9910 - val_loss: 0.7723 - val_accuracy: 0.8000
# Epoch 10/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.7801 - val_accuracy: 0.8000
# Epoch 11/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.8268 - val_accuracy: 0.8800
# Epoch 12/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.7236 - val_accuracy: 0.8800
# Epoch 13/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0603 - accuracy: 0.9865 - val_loss: 1.2996 - val_accuracy: 0.8000
# Epoch 14/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 1.1753 - val_accuracy: 0.8000
# Epoch 15/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.1203 - val_accuracy: 0.7600
# Epoch 16/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 1.5497 - val_accuracy: 0.8000
# Epoch 17/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 1.3167 - val_accuracy: 0.7200
# Epoch 18/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.8572 - val_accuracy: 0.7600
# Epoch 19/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.1872 - val_accuracy: 0.7600
# Epoch 20/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 1.4191 - val_accuracy: 0.7600
# Epoch 21/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.9046 - val_accuracy: 0.8400
# Epoch 22/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0462 - accuracy: 0.9955 - val_loss: 0.9692 - val_accuracy: 0.8800
# Epoch 23/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.7528 - val_accuracy: 0.8800
# Epoch 24/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.8082 - val_accuracy: 0.8800
# Epoch 25/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.9068 - val_accuracy: 0.8800
# Epoch 26/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.9166 - val_accuracy: 0.8800
# Epoch 27/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.0776 - val_accuracy: 0.8800
# Epoch 28/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 1.1579 - val_accuracy: 0.8800
# Epoch 29/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0186 - accuracy: 0.9910 - val_loss: 1.1147 - val_accuracy: 0.8000
# Epoch 30/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 1.0549 - val_accuracy: 0.8800
# Epoch 31/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0161 - accuracy: 0.9955 - val_loss: 0.8365 - val_accuracy: 0.8400
# Epoch 32/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8122 - val_accuracy: 0.8400
# Epoch 33/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7692 - val_accuracy: 0.8800
# Epoch 34/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7727 - val_accuracy: 0.8800
# Epoch 35/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.7303 - val_accuracy: 0.8400
# Epoch 36/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.6863 - val_accuracy: 0.8400
# Epoch 37/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0080 - accuracy: 0.9955 - val_loss: 0.7708 - val_accuracy: 0.8000
# Epoch 38/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.8672 - val_accuracy: 0.8000
# Epoch 39/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0044 - accuracy: 0.9955 - val_loss: 1.1654 - val_accuracy: 0.8000
# Epoch 40/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.1163 - val_accuracy: 0.8000
# Epoch 41/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.0778 - val_accuracy: 0.8000
# Epoch 42/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.1849 - val_accuracy: 0.8000
# Epoch 43/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0100 - accuracy: 0.9955 - val_loss: 1.6955 - val_accuracy: 0.7200
# Epoch 44/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 1.0016 - val_accuracy: 0.8000
# Epoch 45/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8026 - val_accuracy: 0.8800
# Epoch 46/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 1.1718 - val_accuracy: 0.8000
# Epoch 47/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0169 - accuracy: 0.9955 - val_loss: 1.2020 - val_accuracy: 0.8000
# Epoch 48/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0850 - val_accuracy: 0.7600
# Epoch 49/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.2730 - val_accuracy: 0.7600
# Epoch 50/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0189 - accuracy: 0.9955 - val_loss: 1.3676 - val_accuracy: 0.8000
# Epoch 51/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0192 - accuracy: 0.9955 - val_loss: 1.3772 - val_accuracy: 0.7600
# Epoch 52/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.4802 - val_accuracy: 0.7600
# Epoch 53/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0330 - accuracy: 0.9955 - val_loss: 1.2343 - val_accuracy: 0.7600
# Epoch 54/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2343 - val_accuracy: 0.7200
# Epoch 55/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0380 - accuracy: 0.9865 - val_loss: 1.2349 - val_accuracy: 0.7600
# Epoch 56/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.1183 - val_accuracy: 0.8000
# Epoch 57/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2408 - val_accuracy: 0.7600
# Epoch 58/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0204 - accuracy: 0.9955 - val_loss: 1.3739 - val_accuracy: 0.7600
# Epoch 59/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.0996 - val_accuracy: 0.8000
# Epoch 60/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0107 - accuracy: 0.9955 - val_loss: 1.1899 - val_accuracy: 0.7600
# Epoch 61/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0352 - accuracy: 0.9910 - val_loss: 1.3853 - val_accuracy: 0.7600
# Epoch 62/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0297 - accuracy: 0.9910 - val_loss: 1.9349 - val_accuracy: 0.6400
# Epoch 63/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0272 - accuracy: 0.9955 - val_loss: 2.1824 - val_accuracy: 0.7200
# Epoch 64/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0462 - accuracy: 0.9910 - val_loss: 1.6145 - val_accuracy: 0.7200
# Epoch 65/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0636 - accuracy: 0.9910 - val_loss: 1.0300 - val_accuracy: 0.8400
# Epoch 66/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9747 - val_accuracy: 0.8400
# Epoch 67/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0224 - accuracy: 0.9955 - val_loss: 1.1145 - val_accuracy: 0.7600
# Epoch 68/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0206 - accuracy: 0.9955 - val_loss: 2.6435 - val_accuracy: 0.8000
# Epoch 69/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.1033 - accuracy: 0.9730 - val_loss: 1.9370 - val_accuracy: 0.6800
# Epoch 70/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0502 - accuracy: 0.9865 - val_loss: 1.9460 - val_accuracy: 0.7200
# Epoch 71/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0327 - accuracy: 0.9865 - val_loss: 0.8013 - val_accuracy: 0.8400
# Epoch 72/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 1.4812 - val_accuracy: 0.7200
# Epoch 73/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0283 - accuracy: 0.9955 - val_loss: 1.7098 - val_accuracy: 0.7600
# Epoch 74/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0236 - accuracy: 0.9910 - val_loss: 1.1526 - val_accuracy: 0.7600
# Epoch 75/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.1968 - val_accuracy: 0.7600
# Epoch 76/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0190 - accuracy: 0.9955 - val_loss: 1.2020 - val_accuracy: 0.7600
# Epoch 77/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.4733 - val_accuracy: 0.7200
# Epoch 78/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0230 - accuracy: 0.9955 - val_loss: 2.0071 - val_accuracy: 0.7200
# Epoch 79/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.8403 - val_accuracy: 0.7200
# Epoch 80/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.8324 - val_accuracy: 0.7200
# Epoch 81/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0520 - accuracy: 0.9910 - val_loss: 2.8383 - val_accuracy: 0.7200
# Epoch 82/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.9461 - val_accuracy: 0.8000
# Epoch 83/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0436 - accuracy: 0.9955 - val_loss: 1.6388 - val_accuracy: 0.7600
# Epoch 84/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0059 - accuracy: 0.9955 - val_loss: 2.0383 - val_accuracy: 0.8000
# Epoch 85/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0203 - accuracy: 0.9955 - val_loss: 2.3366 - val_accuracy: 0.7200
# Epoch 86/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.6240 - val_accuracy: 0.7600
# Epoch 87/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 2.0509 - val_accuracy: 0.7200
# Epoch 88/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0192 - accuracy: 0.9955 - val_loss: 2.4846 - val_accuracy: 0.6800
# Epoch 89/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0102 - accuracy: 0.9955 - val_loss: 1.5955 - val_accuracy: 0.8000
# Epoch 90/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.4053 - val_accuracy: 0.7600
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 11s 1s/step - loss: 0.2323 - accuracy: 0.9189
# 1/1 [==============================] - 1s 1s/step - loss: 1.4053 - accuracy: 0.7600
# 4
# Epoch 1/90
# 7/7 [==============================] - 117s 13s/step - loss: 0.0245 - accuracy: 0.9955 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 2/90
# 7/7 [==============================] - 103s 15s/step - loss: 0.0580 - accuracy: 0.9865 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 3/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0322 - accuracy: 0.9955 - val_loss: 0.0542 - val_accuracy: 0.9600
# Epoch 4/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9200
# Epoch 5/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0324 - accuracy: 0.9955 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 6/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9200
# Epoch 7/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0183 - accuracy: 0.9955 - val_loss: 0.0881 - val_accuracy: 0.9600
# Epoch 8/90
# 7/7 [==============================] - 102s 15s/step - loss: 0.0235 - accuracy: 0.9955 - val_loss: 0.1594 - val_accuracy: 0.9600
# Epoch 9/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0256 - accuracy: 0.9910 - val_loss: 0.2234 - val_accuracy: 0.9600
# Epoch 10/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9600
# Epoch 11/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0342 - accuracy: 0.9910 - val_loss: 0.2392 - val_accuracy: 0.9600
# Epoch 12/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0654 - accuracy: 0.9910 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 13/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0107 - accuracy: 0.9955 - val_loss: 0.1544 - val_accuracy: 0.9600
# Epoch 14/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 15/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0231 - accuracy: 0.9955 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 16/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.4473 - val_accuracy: 0.9200
# Epoch 17/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0282 - accuracy: 0.9955 - val_loss: 0.4133 - val_accuracy: 0.9200
# Epoch 18/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2485 - val_accuracy: 0.9600
# Epoch 19/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0191 - accuracy: 0.9955 - val_loss: 0.3873 - val_accuracy: 0.9200
# Epoch 20/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0255 - accuracy: 0.9910 - val_loss: 0.4901 - val_accuracy: 0.9200
# Epoch 21/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0095 - accuracy: 0.9955 - val_loss: 0.6406 - val_accuracy: 0.9200
# Epoch 22/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0261 - accuracy: 0.9955 - val_loss: 0.5097 - val_accuracy: 0.8800
# Epoch 23/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0767 - accuracy: 0.9865 - val_loss: 0.5524 - val_accuracy: 0.9200
# Epoch 24/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3817 - val_accuracy: 0.9200
# Epoch 25/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0550 - accuracy: 0.9910 - val_loss: 0.5453 - val_accuracy: 0.9200
# Epoch 26/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0561 - accuracy: 0.9865 - val_loss: 0.3326 - val_accuracy: 0.9600
# Epoch 27/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2790 - val_accuracy: 0.9600
# Epoch 28/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0464 - accuracy: 0.9955 - val_loss: 0.5414 - val_accuracy: 0.9200
# Epoch 29/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 0.9200
# Epoch 30/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5063 - val_accuracy: 0.8800
# Epoch 31/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.5307 - val_accuracy: 0.9200
# Epoch 32/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.9600
# Epoch 33/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.3839 - val_accuracy: 0.9600
# Epoch 34/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5289 - val_accuracy: 0.9600
# Epoch 35/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.7062 - val_accuracy: 0.9200
# Epoch 36/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4934 - val_accuracy: 0.9600
# Epoch 37/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 0.9600
# Epoch 38/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.4034 - val_accuracy: 0.9600
# Epoch 39/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5389 - val_accuracy: 0.9200
# Epoch 40/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2509 - val_accuracy: 0.9600
# Epoch 41/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.1944 - val_accuracy: 0.9600
# Epoch 42/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.9200
# Epoch 43/90
# 7/7 [==============================] - 89s 13s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.6333 - val_accuracy: 0.8800
# Epoch 44/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.4662 - val_accuracy: 0.9200
# Epoch 45/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2962 - val_accuracy: 0.9600
# Epoch 46/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0275 - accuracy: 0.9955 - val_loss: 0.5275 - val_accuracy: 0.8800
# Epoch 47/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.7085 - val_accuracy: 0.8800
# Epoch 48/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0098 - accuracy: 0.9955 - val_loss: 0.3894 - val_accuracy: 0.9600
# Epoch 49/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4222 - val_accuracy: 0.9600
# Epoch 50/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.6704 - val_accuracy: 0.9200
# Epoch 51/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5521 - val_accuracy: 0.9600
# Epoch 52/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.9600
# Epoch 53/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3927 - val_accuracy: 0.9200
# Epoch 54/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9600
# Epoch 55/90
# 7/7 [==============================] - 90s 13s/step - loss: 0.0422 - accuracy: 0.9910 - val_loss: 0.6877 - val_accuracy: 0.8800
# Epoch 56/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.9200
# Epoch 57/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4108 - val_accuracy: 0.9200
# Epoch 58/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.7890 - val_accuracy: 0.8800
# Epoch 59/90
# ...
# 7/7 [==============================] - 94s 13s/step - loss: 0.1855 - accuracy: 0.9459 - val_loss: 1.4742 - val_accuracy: 0.6400
# Epoch 35/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1697 - accuracy: 0.9324 - val_loss: 2.1395 - val_accuracy: 0.6400
# Epoch 36/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.2503 - accuracy: 0.9099 - val_loss: 4.2739 - val_accuracy: 0.6400
# Epoch 37/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1831 - accuracy: 0.9369 - val_loss: 3.4680 - val_accuracy: 0.6400
# Epoch 38/90
# 7/7 [==============================] - 105s 15s/step - loss: 0.2386 - accuracy: 0.9144 - val_loss: 2.6927 - val_accuracy: 0.6400
# Epoch 39/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.2056 - accuracy: 0.9414 - val_loss: 2.6075 - val_accuracy: 0.6400
# Epoch 40/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1810 - accuracy: 0.9369 - val_loss: 3.3290 - val_accuracy: 0.6400
# Epoch 41/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1390 - accuracy: 0.9640 - val_loss: 2.4870 - val_accuracy: 0.6400
# Epoch 42/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.1311 - accuracy: 0.9505 - val_loss: 2.0525 - val_accuracy: 0.6400
# Epoch 43/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.1426 - accuracy: 0.9640 - val_loss: 3.3458 - val_accuracy: 0.6400
# Epoch 44/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1669 - accuracy: 0.9595 - val_loss: 4.2102 - val_accuracy: 0.6400
# Epoch 45/90
# 7/7 [==============================] - 104s 15s/step - loss: 0.1423 - accuracy: 0.9550 - val_loss: 3.9739 - val_accuracy: 0.6400
# Epoch 46/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1511 - accuracy: 0.9550 - val_loss: 3.8228 - val_accuracy: 0.6400
# Epoch 47/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1305 - accuracy: 0.9595 - val_loss: 3.8892 - val_accuracy: 0.6400
# Epoch 48/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0971 - accuracy: 0.9820 - val_loss: 4.0188 - val_accuracy: 0.6400
# Epoch 49/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.1396 - accuracy: 0.9550 - val_loss: 3.0079 - val_accuracy: 0.6400
# Epoch 50/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1565 - accuracy: 0.9595 - val_loss: 4.2712 - val_accuracy: 0.6400
# Epoch 51/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1633 - accuracy: 0.9414 - val_loss: 3.6915 - val_accuracy: 0.6400
# Epoch 52/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1551 - accuracy: 0.9414 - val_loss: 4.2014 - val_accuracy: 0.6400
# Epoch 53/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1103 - accuracy: 0.9640 - val_loss: 4.3774 - val_accuracy: 0.6400
# Epoch 54/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0854 - accuracy: 0.9865 - val_loss: 4.7600 - val_accuracy: 0.6400
# Epoch 55/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1006 - accuracy: 0.9685 - val_loss: 4.6670 - val_accuracy: 0.6400
# Epoch 56/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1105 - accuracy: 0.9685 - val_loss: 4.3931 - val_accuracy: 0.6400
# Epoch 57/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1353 - accuracy: 0.9369 - val_loss: 3.7959 - val_accuracy: 0.6400
# Epoch 58/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0933 - accuracy: 0.9865 - val_loss: 3.3431 - val_accuracy: 0.6400
# Epoch 59/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0963 - accuracy: 0.9685 - val_loss: 3.9323 - val_accuracy: 0.6400
# Epoch 60/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.1284 - accuracy: 0.9595 - val_loss: 3.8275 - val_accuracy: 0.6400
# Epoch 61/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1107 - accuracy: 0.9865 - val_loss: 4.9285 - val_accuracy: 0.6400
# Epoch 62/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1222 - accuracy: 0.9730 - val_loss: 5.3949 - val_accuracy: 0.6400
# Epoch 63/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0695 - accuracy: 0.9775 - val_loss: 5.2424 - val_accuracy: 0.6400
# Epoch 64/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.0743 - accuracy: 0.9730 - val_loss: 4.0531 - val_accuracy: 0.6400
# Epoch 65/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0848 - accuracy: 0.9775 - val_loss: 3.8340 - val_accuracy: 0.6400
# Epoch 66/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.1004 - accuracy: 0.9730 - val_loss: 3.5101 - val_accuracy: 0.6400
# Epoch 67/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.0770 - accuracy: 0.9775 - val_loss: 3.6072 - val_accuracy: 0.6400
# Epoch 68/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0579 - accuracy: 0.9820 - val_loss: 3.9986 - val_accuracy: 0.6400
# Epoch 69/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0898 - accuracy: 0.9775 - val_loss: 4.0003 - val_accuracy: 0.6400
# Epoch 70/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.0628 - accuracy: 0.9865 - val_loss: 4.1188 - val_accuracy: 0.6400
# Epoch 71/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0877 - accuracy: 0.9685 - val_loss: 4.0303 - val_accuracy: 0.6400
# Epoch 72/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0994 - accuracy: 0.9640 - val_loss: 4.1184 - val_accuracy: 0.6400
# Epoch 73/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0542 - accuracy: 0.9865 - val_loss: 4.5118 - val_accuracy: 0.6400
# Epoch 74/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0760 - accuracy: 0.9775 - val_loss: 3.6847 - val_accuracy: 0.6400
# Epoch 75/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.0662 - accuracy: 0.9865 - val_loss: 3.8381 - val_accuracy: 0.6400
# Epoch 76/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0607 - accuracy: 0.9865 - val_loss: 3.5673 - val_accuracy: 0.6400
# Epoch 77/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0577 - accuracy: 0.9910 - val_loss: 2.8137 - val_accuracy: 0.6400
# Epoch 78/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0476 - accuracy: 0.9865 - val_loss: 2.8662 - val_accuracy: 0.6400
# Epoch 79/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0557 - accuracy: 0.9820 - val_loss: 3.1228 - val_accuracy: 0.6400
# Epoch 80/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.1037 - accuracy: 0.9730 - val_loss: 3.5463 - val_accuracy: 0.6400
# Epoch 81/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0414 - accuracy: 0.9865 - val_loss: 3.0374 - val_accuracy: 0.6400
# Epoch 82/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0466 - accuracy: 0.9820 - val_loss: 4.1774 - val_accuracy: 0.6400
# Epoch 83/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0899 - accuracy: 0.9775 - val_loss: 3.2220 - val_accuracy: 0.6400
# Epoch 84/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0508 - accuracy: 0.9910 - val_loss: 3.1946 - val_accuracy: 0.6400
# Epoch 85/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 3.5521 - val_accuracy: 0.6400
# Epoch 86/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0639 - accuracy: 0.9910 - val_loss: 2.7466 - val_accuracy: 0.6000
# Epoch 87/90
# 7/7 [==============================] - 101s 15s/step - loss: 0.0221 - accuracy: 0.9955 - val_loss: 2.4112 - val_accuracy: 0.6000
# Epoch 88/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.0839 - accuracy: 0.9730 - val_loss: 2.4173 - val_accuracy: 0.6000
# Epoch 89/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0731 - accuracy: 0.9820 - val_loss: 1.5127 - val_accuracy: 0.6000
# Epoch 90/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0413 - accuracy: 0.9910 - val_loss: 2.8474 - val_accuracy: 0.6000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 12s 2s/step - loss: 2.6015 - accuracy: 0.6577
# 1/1 [==============================] - 1s 1s/step - loss: 2.8474 - accuracy: 0.6000
# 2
# Epoch 1/90
# 7/7 [==============================] - 128s 15s/step - loss: 0.3701 - accuracy: 0.9414 - val_loss: 2.3028 - val_accuracy: 0.7200
# Epoch 2/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.2863 - accuracy: 0.9414 - val_loss: 3.4369 - val_accuracy: 0.6400
# Epoch 3/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.2154 - accuracy: 0.9369 - val_loss: 1.6006 - val_accuracy: 0.6000
# Epoch 4/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1778 - accuracy: 0.9505 - val_loss: 1.9762 - val_accuracy: 0.7200
# Epoch 5/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.1531 - accuracy: 0.9595 - val_loss: 1.9647 - val_accuracy: 0.7200
# Epoch 6/90
# 7/7 [==============================] - 91s 13s/step - loss: 0.1567 - accuracy: 0.9459 - val_loss: 1.4687 - val_accuracy: 0.5600
# Epoch 7/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.1489 - accuracy: 0.9369 - val_loss: 1.9569 - val_accuracy: 0.7200
# Epoch 8/90
# 7/7 [==============================] - 99s 14s/step - loss: 0.0849 - accuracy: 0.9775 - val_loss: 1.4288 - val_accuracy: 0.6000
# Epoch 9/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0746 - accuracy: 0.9775 - val_loss: 1.8940 - val_accuracy: 0.7200
# Epoch 10/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0797 - accuracy: 0.9730 - val_loss: 1.6786 - val_accuracy: 0.7200
# Epoch 11/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0752 - accuracy: 0.9730 - val_loss: 2.2229 - val_accuracy: 0.6800
# Epoch 12/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.1116 - accuracy: 0.9685 - val_loss: 1.9454 - val_accuracy: 0.7200
# Epoch 13/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0738 - accuracy: 0.9820 - val_loss: 1.3150 - val_accuracy: 0.6800
# Epoch 14/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0563 - accuracy: 0.9820 - val_loss: 1.1440 - val_accuracy: 0.6400
# Epoch 15/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0345 - accuracy: 0.9910 - val_loss: 1.1772 - val_accuracy: 0.6400
# Epoch 16/90
# 7/7 [==============================] - 94s 14s/step - loss: 0.0611 - accuracy: 0.9730 - val_loss: 1.2662 - val_accuracy: 0.6800
# Epoch 17/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0806 - accuracy: 0.9820 - val_loss: 1.5659 - val_accuracy: 0.7200
# Epoch 18/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0551 - accuracy: 0.9865 - val_loss: 2.1562 - val_accuracy: 0.7200
# Epoch 19/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0545 - accuracy: 0.9955 - val_loss: 2.1610 - val_accuracy: 0.7200
# Epoch 20/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0383 - accuracy: 0.9910 - val_loss: 1.6626 - val_accuracy: 0.7200
# Epoch 21/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0456 - accuracy: 0.9910 - val_loss: 1.8163 - val_accuracy: 0.7200
# Epoch 22/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0295 - accuracy: 0.9910 - val_loss: 1.5321 - val_accuracy: 0.7200
# Epoch 23/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0259 - accuracy: 0.9955 - val_loss: 1.4468 - val_accuracy: 0.7200
# Epoch 24/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0758 - accuracy: 0.9865 - val_loss: 2.0195 - val_accuracy: 0.7200
# Epoch 25/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0371 - accuracy: 0.9910 - val_loss: 1.9430 - val_accuracy: 0.7200
# Epoch 26/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.0452 - accuracy: 0.9865 - val_loss: 1.3180 - val_accuracy: 0.6800
# Epoch 27/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.0296 - accuracy: 0.9910 - val_loss: 1.6566 - val_accuracy: 0.7200
# Epoch 28/90
# 7/7 [==============================] - 98s 14s/step - loss: 0.0657 - accuracy: 0.9820 - val_loss: 1.3095 - val_accuracy: 0.7200
# Epoch 29/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0689 - accuracy: 0.9775 - val_loss: 1.4117 - val_accuracy: 0.6800
# Epoch 30/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0212 - accuracy: 0.9955 - val_loss: 1.2125 - val_accuracy: 0.6800
# Epoch 31/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0451 - accuracy: 0.9820 - val_loss: 1.2403 - val_accuracy: 0.6800
# Epoch 32/90
# 7/7 [==============================] - 95s 13s/step - loss: 0.0480 - accuracy: 0.9865 - val_loss: 1.8065 - val_accuracy: 0.6800
# Epoch 33/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0494 - accuracy: 0.9910 - val_loss: 1.3344 - val_accuracy: 0.7200
# Epoch 34/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0432 - accuracy: 0.9910 - val_loss: 1.3076 - val_accuracy: 0.6800
# Epoch 35/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0425 - accuracy: 0.9865 - val_loss: 1.4379 - val_accuracy: 0.7200
# Epoch 36/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0749 - accuracy: 0.9730 - val_loss: 1.6378 - val_accuracy: 0.6800
# Epoch 37/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0665 - accuracy: 0.9820 - val_loss: 1.2093 - val_accuracy: 0.7200
# Epoch 38/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0478 - accuracy: 0.9865 - val_loss: 1.1015 - val_accuracy: 0.7600
# Epoch 39/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0792 - accuracy: 0.9820 - val_loss: 1.0411 - val_accuracy: 0.8400
# Epoch 40/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0474 - accuracy: 0.9865 - val_loss: 1.7469 - val_accuracy: 0.6800
# Epoch 41/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0439 - accuracy: 0.9865 - val_loss: 1.2341 - val_accuracy: 0.8000
# Epoch 42/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0322 - accuracy: 0.9910 - val_loss: 1.5316 - val_accuracy: 0.7200
# Epoch 43/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0208 - accuracy: 0.9955 - val_loss: 1.5200 - val_accuracy: 0.7600
# Epoch 44/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.5403 - val_accuracy: 0.7200
# Epoch 45/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0546 - accuracy: 0.9865 - val_loss: 1.7152 - val_accuracy: 0.6800
# Epoch 46/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0268 - accuracy: 0.9910 - val_loss: 1.3088 - val_accuracy: 0.7600
# Epoch 47/90
# 7/7 [==============================] - 92s 13s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.2123 - val_accuracy: 0.7600
# Epoch 48/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 1.1555 - val_accuracy: 0.7600
# Epoch 49/90
# 7/7 [==============================] - 93s 13s/step - loss: 0.0185 - accuracy: 0.9955 - val_loss: 1.3442 - val_accuracy: 0.7600
# Epoch 50/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0568 - accuracy: 0.9865 - val_loss: 1.3835 - val_accuracy: 0.7600
# Epoch 51/90
# 7/7 [==============================] - 94s 13s/step - loss: 0.0248 - accuracy: 0.9910 - val_loss: 1.8933 - val_accuracy: 0.6800
# Epoch 52/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0167 - accuracy: 0.9955 - val_loss: 2.3163 - val_accuracy: 0.6400
# Epoch 53/90
# 7/7 [==============================] - 95s 14s/step - loss: 0.0248 - accuracy: 0.9955 - val_loss: 1.7399 - val_accuracy: 0.6400
# Epoch 54/90
# 7/7 [==============================] - 96s 14s/step - loss: 0.0353 - accuracy: 0.9910 - val_loss: 1.5121 - val_accuracy: 0.7200
# Epoch 55/90
# 7/7 [==============================] - 97s 14s/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.5106 - val_accuracy: 0.6800
# Epoch 56/90
# 1/7 [===>..........................] - ETA: 1:17 - loss: 0.0653 - accuracy: 0.9688

# %%
i

# %%
scipy.io.savemat('cancer_NC_output_90/total_accuracy_tr.mat', mdict={'total_accuracy_tr': total_accuracy_tr})
scipy.io.savemat('cancer_NC_output_90/total_accuracy_te.mat', mdict={'total_accuracy_te': total_accuracy_te})


scipy.io.savemat('cancer_NC_output_90/total_confusion_matrix_1_last.mat', mdict={'total_confusion_matrix_1_last': total_confusion_matrix_1_last})

scipy.io.savemat('cancer_NC_output_90/mean_fpr_t.mat', mdict={'mean_fpr_t': mean_fpr_t})
scipy.io.savemat('cancer_NC_output_90/mean_tpr_t.mat', mdict={'mean_tpr_t': mean_tpr_t})
scipy.io.savemat('cancer_NC_output_90/mean_auc_t.mat', mdict={'mean_auc_t': mean_auc_t})
