# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow.keras import models , layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D,BatchNormalization ,Flatten ,Reshape  ,RepeatVector ,Concatenate
from tensorflow.keras.layers import  Conv2D,LSTM ,Bidirectional  ,Input,Embedding  ,GlobalMaxPool1D ,TimeDistributed

from tensorflow.keras.layers import Activation,MaxPooling2D,AveragePooling3D,GlobalMaxPool2D,AveragePooling2D
from tensorflow.keras.layers import MaxPooling3D,GlobalAveragePooling3D,GlobalMaxPool3D,Conv3D

from sklearn.model_selection import train_test_split ,StratifiedKFold ,KFold ,RepeatedKFold
from sklearn import preprocessing

from tensorflow.keras import Model 

from keras.utils import np_utils

from sklearn.cluster import KMeans
from sklearn import cluster


import matplotlib.pyplot as plt
import numpy as np
import scipy.io
import os

import pylab as pl

from scipy import interp
from itertools import cycle
import matplotlib.patches as patches


from sklearn.metrics import accuracy_score ,roc_curve, auc ,roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


def invert_permutation(p):
    '''The argument p is assumed to be some permutation of 0, 1, ..., len(p)-1. 
    Returns an array s, where s[i] gives the index of i in p.
    '''
    s = np.empty(p.size, p.dtype)
    s[p] = np.arange(p.size)
    return s


from tensorflow.keras import backend as K
def pearson_r(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x, axis=0)
    my = K.mean(y, axis=0)
    xm, ym = x - mx, y - my
    r_num = K.sum(xm * ym)
    x_square_sum = K.sum(xm * xm)
    y_square_sum = K.sum(ym * ym)
    r_den = K.sqrt(x_square_sum * y_square_sum)
    r = r_num / r_den
    return K.mean(r)



import os 
from PIL import Image
import numpy as np
from numpy import *   

from matplotlib import pyplot as plt
from IPython import display


from patchify import patchify, unpatchify


import matplotlib.pyplot as plt
# %pylab inline
# %load_ext tensorboard
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Aya\anaconda3\envs\tf-gpu\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['display']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
def cancer_NC(splits , epochs,batch_size):


    mat_sc= scipy.io.loadmat('cancer_img_p')
    cancer_img_p = mat_sc['cancer_img_p']

    mat_sc= scipy.io.loadmat('normal_img_p')
    normal_img_p = mat_sc['normal_img_p']

    labels_cancer_ = np.ones((cancer_img_p.shape[0],1))
    labels_normal_ = np.zeros((normal_img_p.shape[0],1))



    x_cancer_NC_ = np.concatenate((cancer_img_p, normal_img_p), axis=0) 
    y_cancer_NC_ = np.concatenate((labels_cancer_, labels_normal_), axis=0) 

    x_cancer_NC_=np.asarray(tf.expand_dims(x_cancer_NC_, axis=-1))





    x_cancer_NC_1 = x_cancer_NC_[:,0,0]
    x_cancer_NC_2 = x_cancer_NC_[:,1,0]
    x_cancer_NC_3 = x_cancer_NC_[:,2,0]
    x_cancer_NC_4 = x_cancer_NC_[:,3,0]
    x_cancer_NC_5 = x_cancer_NC_[:,4,0]
    x_cancer_NC_6 = x_cancer_NC_[:,5,0]

    x_cancer_NC_7 = x_cancer_NC_[:,6,0]
    x_cancer_NC_8 = x_cancer_NC_[:,7,0]
    x_cancer_NC_9 = x_cancer_NC_[:,8,0]
    x_cancer_NC_10 = x_cancer_NC_[:,9,0]
    x_cancer_NC_11 = x_cancer_NC_[:,10,0]




    n = x_cancer_NC_1.shape[0]
    permutation = list(np.random.permutation(n))
    x_cancer_NC_1 = x_cancer_NC_1[permutation]
    x_cancer_NC_2 = x_cancer_NC_2[permutation]
    x_cancer_NC_3 = x_cancer_NC_3[permutation]
    x_cancer_NC_4 = x_cancer_NC_4[permutation]
    x_cancer_NC_5 = x_cancer_NC_5[permutation]
    x_cancer_NC_6 = x_cancer_NC_6[permutation]


    x_cancer_NC_7 = x_cancer_NC_7[permutation]
    x_cancer_NC_8 = x_cancer_NC_8[permutation]
    x_cancer_NC_9 = x_cancer_NC_9[permutation]
    x_cancer_NC_10 = x_cancer_NC_10[permutation]
    x_cancer_NC_11 = x_cancer_NC_11[permutation]




    y_cancer_NC_ = y_cancer_NC_[permutation]

    permutation_xray = np.asarray(permutation)




    input_1 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_1'


    conv_1 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_1)
    print(conv_1.shape)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Dropout(rate=0.5)(conv_1)


    conv_1 = AveragePooling2D()(conv_1)












    input_2 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_2')

    conv_2 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)



    conv_2 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_2)
    print(conv_2.shape)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Dropout(rate=0.5)(conv_2)


    conv_2 = AveragePooling2D()(conv_2)







    input_3= tf.keras.layers.Input(shape=[256, 256,1], name='main_input_3')

    conv_3 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)



    conv_3 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_3)
    print(conv_3.shape)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Dropout(rate=0.5)(conv_3)


    conv_3 = AveragePooling2D()(conv_3)





    input_4= tf.keras.layers.Input(shape=[256, 256,1], name='main_input_4')


    conv_4 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)



    conv_4 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_4)
    print(conv_4.shape)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Dropout(rate=0.5)(conv_4)


    conv_4 = AveragePooling2D()(conv_4)







    input_5 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_5')

    conv_5 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)



    conv_5 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_5)
    print(conv_5.shape)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Dropout(rate=0.5)(conv_5)


    conv_5 = AveragePooling2D()(conv_5)





    input_6 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_6')


    conv_6 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)



    conv_6 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_6)
    print(conv_6.shape)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Dropout(rate=0.5)(conv_6)


    conv_6 = AveragePooling2D()(conv_6)




    input_7 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_7')



    conv_7 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)



    conv_7 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_7)
    print(conv_7.shape)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Dropout(rate=0.5)(conv_7)


    conv_7 = AveragePooling2D()(conv_7)







    input_8 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_8')



    conv_8 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)



    conv_8 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_8)
    print(conv_8.shape)
    conv_8 = BatchNormalization()(conv_8)
    conv_8 = Dropout(rate=0.5)(conv_8)


    conv_8 = AveragePooling2D()(conv_8)






    input_9 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_9')



    conv_9 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)



    conv_9 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_9)
    print(conv_9.shape)
    conv_9 = BatchNormalization()(conv_9)
    conv_9 = Dropout(rate=0.5)(conv_9)


    conv_9 = AveragePooling2D()(conv_9)





    input_10 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_10')



    conv_10 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)



    conv_10 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_10)
    print(conv_10.shape)
    conv_10 = BatchNormalization()(conv_10)
    conv_10 = Dropout(rate=0.5)(conv_10)


    conv_10 = AveragePooling2D()(conv_10)






    input_11 = tf.keras.layers.Input(shape=[256, 256,1], name='main_input_11')



    conv_11 = layers.Conv2D(32, (2, 2), strides=(2, 2),activation="relu")(input_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = layers.Conv2D(64, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)



    conv_11 = layers.Conv2D(128, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = layers.Conv2D(256, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = layers.Conv2D(512, (2, 2), strides=(2, 2),activation="relu" )(conv_11)
    print(conv_11.shape)
    conv_11 = BatchNormalization()(conv_11)
    conv_11 = Dropout(rate=0.5)(conv_11)


    conv_11 = AveragePooling2D()(conv_11)











    x = Concatenate(axis =-1)([conv_1,conv_2])
    x = Concatenate(axis =-1)([x,conv_3])
    x = Concatenate(axis =-1)([x,conv_4])
    x = Concatenate(axis =-1)([x,conv_5])
    x = Concatenate(axis =-1)([x,conv_6])

    x = Concatenate(axis =-1)([x,conv_7])
    x = Concatenate(axis =-1)([x,conv_8])
    x = Concatenate(axis =-1)([x,conv_9])
    x = Concatenate(axis =-1)([x,conv_10])
    x = Concatenate(axis =-1)([x,conv_11])




    x_4 = tf.keras.layers.Flatten()(x)
    print(x_4.shape)

    x_4 = tf.keras.layers.Dense(64,  name="layer_dense")(x_4)

    x_4 = tf.keras.layers.Dense(2, activation='softmax' , name="layer_x")(x_4)


    adam = tf.keras.optimizers.Adam( lr=1e-4)

    model = tf.keras.Model(inputs= [input_1,input_2,input_3,input_4,input_5,input_6,
                                   input_7,input_8,input_9,input_10,input_11], outputs= x_4)

    model.compile(optimizer= adam , 
                      loss= { 'layer_x':'binary_crossentropy'},
                      metrics={ 'layer_x':'accuracy'})




    kfold = StratifiedKFold(n_splits=splits,  random_state=np.random.seed(0))


    accuracy_train_x_=[]
    accuracy_test_x_=[] 

    mean_tpr = 0.0
    mean_fpr = np.linspace(0, 1, 100)
    all_tpr = []


    accuracy_tr_all=[]
    accuracy_te_all=[]

    confusion_matrix_1_last =[]
 

    count = 1
    for train_index, test_index in kfold.split(x_cancer_NC_1, y_cancer_NC_):
        print(count)
        count = count+1

        x_train_1, x_test_1 = x_cancer_NC_1[train_index], x_cancer_NC_1[test_index]
        y_train, y_test = y_cancer_NC_[train_index], y_cancer_NC_[test_index]
        
        

        x_train_2, x_test_2 = x_cancer_NC_2[train_index], x_cancer_NC_2[test_index]
        x_train_3, x_test_3 = x_cancer_NC_3[train_index], x_cancer_NC_3[test_index]
        x_train_4, x_test_4 = x_cancer_NC_4[train_index], x_cancer_NC_4[test_index]
        x_train_5, x_test_5 = x_cancer_NC_5[train_index], x_cancer_NC_5[test_index]
        x_train_6, x_test_6 = x_cancer_NC_6[train_index], x_cancer_NC_6[test_index]

        
        x_train_7, x_test_7 = x_cancer_NC_7[train_index], x_cancer_NC_7[test_index]
        x_train_8, x_test_8 = x_cancer_NC_8[train_index], x_cancer_NC_8[test_index]
        x_train_9, x_test_9 = x_cancer_NC_9[train_index], x_cancer_NC_9[test_index]
        x_train_10, x_test_10 = x_cancer_NC_10[train_index], x_cancer_NC_10[test_index]
        x_train_11, x_test_11 = x_cancer_NC_11[train_index], x_cancer_NC_11[test_index]

             

        ## normalization : normalize each feature for norm = 1
        # axis 0 for columns ( features) and axis 1 for rows for this function
        # f.keras.utils.normalize() and also this function make l2 norm according to the chosen axis

        x_train_1 = tf.keras.utils.normalize(x_train_1, axis=1)
        x_train_2 = tf.keras.utils.normalize(x_train_2, axis=1)
        x_train_3 = tf.keras.utils.normalize(x_train_3, axis=1)
        x_train_4 = tf.keras.utils.normalize(x_train_4, axis=1)
        x_train_5 = tf.keras.utils.normalize(x_train_5, axis=1)
        x_train_6 = tf.keras.utils.normalize(x_train_6, axis=1)
        
        x_train_7 = tf.keras.utils.normalize(x_train_7, axis=1)
        x_train_8 = tf.keras.utils.normalize(x_train_8, axis=1)
        x_train_9 = tf.keras.utils.normalize(x_train_9, axis=1)
        x_train_10 = tf.keras.utils.normalize(x_train_10, axis=1)
        x_train_11 = tf.keras.utils.normalize(x_train_11, axis=1)
        
        
       
        x_test_1 = tf.keras.utils.normalize(x_test_1, axis=1)
        x_test_2 = tf.keras.utils.normalize(x_test_2, axis=1)
        x_test_3 = tf.keras.utils.normalize(x_test_3, axis=1)
        x_test_4 = tf.keras.utils.normalize(x_test_4, axis=1)
        x_test_5 = tf.keras.utils.normalize(x_test_5, axis=1)
        x_test_6 = tf.keras.utils.normalize(x_test_6, axis=1)
        
        x_test_7 = tf.keras.utils.normalize(x_test_7, axis=1)
        x_test_8 = tf.keras.utils.normalize(x_test_8, axis=1)
        x_test_9 = tf.keras.utils.normalize(x_test_9, axis=1)
        x_test_10 = tf.keras.utils.normalize(x_test_10, axis=1)
        x_test_11 = tf.keras.utils.normalize(x_test_11, axis=1)
        
        
       
        ## two output for classification
        
    
        ## two output for classification

        uniques_y_test, ids_y_test = np.unique(y_test, return_inverse=True)   
        
        
        y_train = np_utils.to_categorical(y_train, num_classes=2)
        y_test  =  np_utils.to_categorical(y_test, num_classes=2)


        history = model.fit([x_train_1,x_train_2,x_train_3,x_train_4,x_train_5,x_train_6,
                            x_train_7,x_train_8,x_train_9,x_train_10,x_train_11], y_train, 
                            epochs=epochs, batch_size=batch_size , 
                            validation_data=( [x_test_1,x_test_2,x_test_3,x_test_4,x_test_5,x_test_6,
                                              x_test_7,x_test_8,x_test_9,x_test_10,x_test_11] , y_test))

        

        
        
        
        print(history.history.keys())
        a,accuracy_train_x = model.evaluate([x_train_1,x_train_2,x_train_3,x_train_4,x_train_5,x_train_6,
                                            x_train_7,x_train_8,x_train_9,x_train_10,x_train_11],y_train)

        a, accuracy_test_x = model.evaluate([x_test_1,x_test_2,x_test_3,x_test_4,x_test_5,x_test_6,
                                            x_test_7,x_test_8,x_test_9,x_test_10,x_test_11],y_test)

        accuracy_train_x_.append(accuracy_train_x)

        accuracy_test_x_.append(accuracy_test_x)   
   



        # classification paramaters


        yhat_probs = model.predict([x_test_1,x_test_2,x_test_3,x_test_4,x_test_5,x_test_6,
                                                      x_test_7,x_test_8,x_test_9,x_test_10,x_test_11])


        yhat_classes =yhat_probs>0.5
        yhat_classes_1 =  1*yhat_classes 


        # confusion matrix
        y_test_con = uniques_y_test[y_test.argmax(1)]
        yhat_classes_1_con = uniques_y_test[yhat_classes_1.argmax(1)]

        confusion_matrix_1_last.append(confusion_matrix(y_test_con, yhat_classes_1_con,labels=[0, 1]))


        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve( y_cancer_NC_[test_index], yhat_classes_1_con)  
        mean_tpr += interp(mean_fpr, fpr, tpr)
        mean_tpr[0] = 0.0
        roc_auc = auc(fpr, tpr)
        

    mean_tpr /= splits
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)

    

    
    
    return    accuracy_train_x_,accuracy_test_x_,confusion_matrix_1_last,mean_fpr,mean_tpr,mean_auc

# %%
iteration = 10
splits = 10
epochs= 50
batch_size=32


    
total_accuracy_tr =  np.zeros( (iteration,splits), dtype=np.float32) 
total_accuracy_te =  np.zeros( (iteration,splits), dtype=np.float32) 
total_confusion_matrix_1_last =  np.zeros( (iteration,splits,2,2), dtype=np.float32) 


mean_fpr_t =  np.zeros( (iteration,100), dtype=np.float32) 
mean_tpr_t =  np.zeros( (iteration,100), dtype=np.float32) 
mean_auc_t =  np.zeros( (iteration,1), dtype=np.float32) 




for i in list(range(iteration)):
    accuracy_tr_all,accuracy_te_all, confusion_matrix_1_last,mean_fpr,mean_tpr,mean_auc  = cancer_NC(splits , epochs,batch_size)


    
    total_accuracy_tr[i , ] =   accuracy_tr_all       
    total_accuracy_te[i , ] =   accuracy_te_all       
   
    total_confusion_matrix_1_last[i , ] =   confusion_matrix_1_last       


    
    mean_fpr_t[i , ]  =  mean_fpr      
    mean_tpr_t[i , ]  =  mean_tpr
    mean_auc_t[i , ]  =  mean_auc
# Out:
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 128, 128, 32)
# (None, 64, 64, 64)
# (None, 32, 32, 128)
# (None, 16, 16, 256)
# (None, 8, 8, 512)
# (None, 90112)
# C:\Users\Aya\anaconda3\envs\tf-gpu\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 1
# Epoch 1/50
# 7/7 [==============================] - 142s 14s/step - loss: 1.1025 - accuracy: 0.5991 - val_loss: 0.7774 - val_accuracy: 0.3600
# Epoch 2/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.8280 - accuracy: 0.6847 - val_loss: 0.6837 - val_accuracy: 0.6400
# Epoch 3/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.7956 - accuracy: 0.6757 - val_loss: 0.6720 - val_accuracy: 0.6400
# Epoch 4/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.6015 - accuracy: 0.7658 - val_loss: 0.7901 - val_accuracy: 0.3600
# Epoch 5/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.5963 - accuracy: 0.7838 - val_loss: 0.7668 - val_accuracy: 0.3600
# Epoch 6/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.5653 - accuracy: 0.7973 - val_loss: 0.8023 - val_accuracy: 0.3600
# Epoch 7/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.5353 - accuracy: 0.8153 - val_loss: 0.7876 - val_accuracy: 0.3600
# Epoch 8/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.4174 - accuracy: 0.8333 - val_loss: 0.7460 - val_accuracy: 0.3600
# Epoch 9/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.4276 - accuracy: 0.8378 - val_loss: 0.8013 - val_accuracy: 0.3600
# Epoch 10/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.4259 - accuracy: 0.8288 - val_loss: 0.9079 - val_accuracy: 0.3600
# Epoch 11/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.4614 - accuracy: 0.8423 - val_loss: 0.6836 - val_accuracy: 0.6400
# Epoch 12/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.5096 - accuracy: 0.7973 - val_loss: 0.9698 - val_accuracy: 0.3600
# Epoch 13/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.4586 - accuracy: 0.8333 - val_loss: 0.6586 - val_accuracy: 0.6400
# Epoch 14/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.3778 - accuracy: 0.8514 - val_loss: 0.7295 - val_accuracy: 0.3600
# Epoch 15/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.3185 - accuracy: 0.8964 - val_loss: 0.6701 - val_accuracy: 0.6400
# Epoch 16/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.3023 - accuracy: 0.9144 - val_loss: 0.6699 - val_accuracy: 0.6400
# Epoch 17/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.2921 - accuracy: 0.8829 - val_loss: 0.6556 - val_accuracy: 0.6400
# Epoch 18/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.3377 - accuracy: 0.8964 - val_loss: 0.6687 - val_accuracy: 0.6400
# Epoch 19/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.3328 - accuracy: 0.8784 - val_loss: 0.7354 - val_accuracy: 0.6400
# Epoch 20/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.2623 - accuracy: 0.9144 - val_loss: 0.7227 - val_accuracy: 0.6400
# Epoch 21/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.2610 - accuracy: 0.9279 - val_loss: 0.8445 - val_accuracy: 0.6400
# Epoch 22/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.2616 - accuracy: 0.8964 - val_loss: 0.7200 - val_accuracy: 0.6400
# Epoch 23/50
# 7/7 [==============================] - 121s 18s/step - loss: 0.2622 - accuracy: 0.8964 - val_loss: 0.6878 - val_accuracy: 0.6400
# Epoch 24/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.2511 - accuracy: 0.9234 - val_loss: 0.6720 - val_accuracy: 0.6400
# Epoch 25/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.2382 - accuracy: 0.9189 - val_loss: 0.7227 - val_accuracy: 0.3600
# Epoch 26/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.2448 - accuracy: 0.9324 - val_loss: 0.6694 - val_accuracy: 0.6400
# Epoch 27/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.2486 - accuracy: 0.9099 - val_loss: 0.6943 - val_accuracy: 0.6400
# Epoch 28/50
# 7/7 [==============================] - 102s 15s/step - loss: 0.2866 - accuracy: 0.9099 - val_loss: 1.0484 - val_accuracy: 0.6400
# Epoch 29/50
# 7/7 [==============================] - 124s 16s/step - loss: 0.2045 - accuracy: 0.9324 - val_loss: 0.6762 - val_accuracy: 0.6400
# Epoch 30/50
# 7/7 [==============================] - 104s 15s/step - loss: 0.2611 - accuracy: 0.8964 - val_loss: 1.1507 - val_accuracy: 0.6400
# Epoch 31/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.2588 - accuracy: 0.9189 - val_loss: 0.7561 - val_accuracy: 0.6400
# Epoch 32/50
# 7/7 [==============================] - 106s 15s/step - loss: 0.1475 - accuracy: 0.9459 - val_loss: 0.6688 - val_accuracy: 0.6400
# Epoch 33/50
# 7/7 [==============================] - 108s 15s/step - loss: 0.1443 - accuracy: 0.9505 - val_loss: 0.8012 - val_accuracy: 0.6400
# Epoch 34/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.2159 - accuracy: 0.9324 - val_loss: 1.2377 - val_accuracy: 0.6400
# Epoch 35/50
# 7/7 [==============================] - 107s 15s/step - loss: 0.2434 - accuracy: 0.9144 - val_loss: 0.8305 - val_accuracy: 0.6400
# Epoch 36/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.2257 - accuracy: 0.9189 - val_loss: 1.9000 - val_accuracy: 0.6400
# Epoch 37/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.2132 - accuracy: 0.9279 - val_loss: 0.8398 - val_accuracy: 0.6400
# Epoch 38/50
# 7/7 [==============================] - 104s 15s/step - loss: 0.2350 - accuracy: 0.9459 - val_loss: 0.9958 - val_accuracy: 0.6400
# Epoch 39/50
# 7/7 [==============================] - 102s 15s/step - loss: 0.1661 - accuracy: 0.9414 - val_loss: 0.7298 - val_accuracy: 0.6400
# Epoch 40/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.1403 - accuracy: 0.9595 - val_loss: 0.9721 - val_accuracy: 0.6400
# Epoch 41/50
# 7/7 [==============================] - 106s 15s/step - loss: 0.1296 - accuracy: 0.9595 - val_loss: 1.0750 - val_accuracy: 0.6400
# Epoch 42/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.1034 - accuracy: 0.9685 - val_loss: 0.9443 - val_accuracy: 0.6400
# Epoch 43/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.1168 - accuracy: 0.9550 - val_loss: 1.5175 - val_accuracy: 0.6400
# Epoch 44/50
# 7/7 [==============================] - 108s 15s/step - loss: 0.1501 - accuracy: 0.9369 - val_loss: 2.0347 - val_accuracy: 0.6400
# Epoch 45/50
# 7/7 [==============================] - 106s 15s/step - loss: 0.1673 - accuracy: 0.9595 - val_loss: 2.3881 - val_accuracy: 0.6400
# Epoch 46/50
# 7/7 [==============================] - 107s 15s/step - loss: 0.1580 - accuracy: 0.9505 - val_loss: 2.2284 - val_accuracy: 0.6400
# Epoch 47/50
# 7/7 [==============================] - 115s 17s/step - loss: 0.1356 - accuracy: 0.9640 - val_loss: 1.9390 - val_accuracy: 0.6400
# Epoch 48/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.1430 - accuracy: 0.9550 - val_loss: 0.9193 - val_accuracy: 0.6400
# Epoch 49/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.1190 - accuracy: 0.9640 - val_loss: 1.0819 - val_accuracy: 0.6400
# Epoch 50/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.1004 - accuracy: 0.9775 - val_loss: 1.2116 - val_accuracy: 0.6400
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 12s 2s/step - loss: 1.1218 - accuracy: 0.6216
# 1/1 [==============================] - 2s 2s/step - loss: 1.2116 - accuracy: 0.6400
# 2
# Epoch 1/50
# 7/7 [==============================] - 123s 15s/step - loss: 0.2615 - accuracy: 0.9279 - val_loss: 1.4233 - val_accuracy: 0.6400
# Epoch 2/50
# 7/7 [==============================] - 102s 15s/step - loss: 0.2423 - accuracy: 0.9234 - val_loss: 2.2764 - val_accuracy: 0.6400
# Epoch 3/50
# 7/7 [==============================] - 102s 15s/step - loss: 0.2757 - accuracy: 0.9144 - val_loss: 2.4015 - val_accuracy: 0.6400
# Epoch 4/50
# 7/7 [==============================] - 101s 14s/step - loss: 0.1948 - accuracy: 0.9505 - val_loss: 2.0795 - val_accuracy: 0.6400
# Epoch 5/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.1607 - accuracy: 0.9595 - val_loss: 0.6598 - val_accuracy: 0.6400
# Epoch 6/50
# 7/7 [==============================] - 102s 15s/step - loss: 0.2087 - accuracy: 0.9550 - val_loss: 0.7642 - val_accuracy: 0.6400
# Epoch 7/50
# 7/7 [==============================] - 104s 15s/step - loss: 0.1463 - accuracy: 0.9459 - val_loss: 1.3018 - val_accuracy: 0.6400
# Epoch 8/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.1469 - accuracy: 0.9505 - val_loss: 1.7831 - val_accuracy: 0.6400
# Epoch 9/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.1634 - accuracy: 0.9550 - val_loss: 2.2089 - val_accuracy: 0.6400
# Epoch 10/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.1044 - accuracy: 0.9685 - val_loss: 2.1700 - val_accuracy: 0.6400
# Epoch 11/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.1175 - accuracy: 0.9685 - val_loss: 2.0222 - val_accuracy: 0.6400
# Epoch 12/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.1418 - accuracy: 0.9640 - val_loss: 1.1684 - val_accuracy: 0.6400
# Epoch 13/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.1392 - accuracy: 0.9595 - val_loss: 0.8390 - val_accuracy: 0.6400
# Epoch 14/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.1179 - accuracy: 0.9595 - val_loss: 1.3750 - val_accuracy: 0.6400
# Epoch 15/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.1543 - accuracy: 0.9550 - val_loss: 1.4944 - val_accuracy: 0.6400
# Epoch 16/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0594 - accuracy: 0.9910 - val_loss: 2.1240 - val_accuracy: 0.6400
# Epoch 17/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.1113 - accuracy: 0.9730 - val_loss: 2.0388 - val_accuracy: 0.6400
# Epoch 18/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.1131 - accuracy: 0.9730 - val_loss: 2.6640 - val_accuracy: 0.6400
# Epoch 19/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0727 - accuracy: 0.9685 - val_loss: 2.4323 - val_accuracy: 0.6400
# Epoch 20/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0853 - accuracy: 0.9865 - val_loss: 2.7700 - val_accuracy: 0.6400
# Epoch 21/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.1075 - accuracy: 0.9730 - val_loss: 1.7857 - val_accuracy: 0.6400
# Epoch 22/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0733 - accuracy: 0.9730 - val_loss: 1.3392 - val_accuracy: 0.6400
# Epoch 23/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0522 - accuracy: 0.9820 - val_loss: 1.8269 - val_accuracy: 0.6400
# Epoch 24/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0915 - accuracy: 0.9685 - val_loss: 1.3572 - val_accuracy: 0.6400
# Epoch 25/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0752 - accuracy: 0.9775 - val_loss: 0.9320 - val_accuracy: 0.7200
# Epoch 26/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0582 - accuracy: 0.9820 - val_loss: 0.7741 - val_accuracy: 0.7600
# Epoch 27/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0846 - accuracy: 0.9730 - val_loss: 0.6980 - val_accuracy: 0.7200
# Epoch 28/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0865 - accuracy: 0.9775 - val_loss: 0.7012 - val_accuracy: 0.6800
# Epoch 29/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0452 - accuracy: 0.9910 - val_loss: 0.7565 - val_accuracy: 0.6800
# Epoch 30/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0503 - accuracy: 0.9910 - val_loss: 0.9638 - val_accuracy: 0.7600
# Epoch 31/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0808 - accuracy: 0.9820 - val_loss: 0.7580 - val_accuracy: 0.7200
# Epoch 32/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0498 - accuracy: 0.9865 - val_loss: 0.6675 - val_accuracy: 0.7600
# Epoch 33/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0609 - accuracy: 0.9775 - val_loss: 0.7436 - val_accuracy: 0.7200
# Epoch 34/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0767 - accuracy: 0.9730 - val_loss: 0.8231 - val_accuracy: 0.7200
# Epoch 35/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0469 - accuracy: 0.9955 - val_loss: 1.0895 - val_accuracy: 0.7600
# Epoch 36/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0433 - accuracy: 0.9910 - val_loss: 0.8364 - val_accuracy: 0.7200
# Epoch 37/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0467 - accuracy: 0.9775 - val_loss: 0.9167 - val_accuracy: 0.7200
# Epoch 38/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0470 - accuracy: 0.9865 - val_loss: 1.2223 - val_accuracy: 0.7200
# Epoch 39/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0596 - accuracy: 0.9820 - val_loss: 1.0432 - val_accuracy: 0.6800
# Epoch 40/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0594 - accuracy: 0.9955 - val_loss: 0.9083 - val_accuracy: 0.7200
# Epoch 41/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0701 - accuracy: 0.9820 - val_loss: 1.0767 - val_accuracy: 0.7200
# Epoch 42/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0352 - accuracy: 0.9955 - val_loss: 1.0921 - val_accuracy: 0.8000
# Epoch 43/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0287 - accuracy: 0.9955 - val_loss: 1.0065 - val_accuracy: 0.7200
# Epoch 44/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0575 - accuracy: 0.9820 - val_loss: 0.9962 - val_accuracy: 0.7200
# Epoch 45/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0426 - accuracy: 0.9910 - val_loss: 1.0589 - val_accuracy: 0.7200
# Epoch 46/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 1.0377 - val_accuracy: 0.7200
# Epoch 47/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0676 - accuracy: 0.9820 - val_loss: 1.0559 - val_accuracy: 0.7200
# Epoch 48/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0472 - accuracy: 0.9865 - val_loss: 1.0158 - val_accuracy: 0.7200
# Epoch 49/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0310 - accuracy: 0.9910 - val_loss: 1.0242 - val_accuracy: 0.7200
# Epoch 50/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0540 - accuracy: 0.9865 - val_loss: 1.1302 - val_accuracy: 0.7200
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 15s 2s/step - loss: 0.6896 - accuracy: 0.8198
# 1/1 [==============================] - 2s 2s/step - loss: 1.1302 - accuracy: 0.7200
# 3
# Epoch 1/50
# 7/7 [==============================] - 153s 19s/step - loss: 0.0971 - accuracy: 0.9685 - val_loss: 0.6540 - val_accuracy: 0.7600
# Epoch 2/50
# 7/7 [==============================] - 110s 16s/step - loss: 0.1029 - accuracy: 0.9730 - val_loss: 0.7363 - val_accuracy: 0.8000
# Epoch 3/50
# 7/7 [==============================] - 109s 16s/step - loss: 0.1055 - accuracy: 0.9775 - val_loss: 0.8390 - val_accuracy: 0.7600
# Epoch 4/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.0774 - accuracy: 0.9820 - val_loss: 0.7165 - val_accuracy: 0.7600
# Epoch 5/50
# 7/7 [==============================] - 108s 15s/step - loss: 0.0791 - accuracy: 0.9775 - val_loss: 0.8744 - val_accuracy: 0.7600
# Epoch 6/50
# 7/7 [==============================] - 109s 16s/step - loss: 0.0469 - accuracy: 0.9910 - val_loss: 0.8734 - val_accuracy: 0.7200
# Epoch 7/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.0476 - accuracy: 0.9820 - val_loss: 1.6923 - val_accuracy: 0.7200
# Epoch 8/50
# 7/7 [==============================] - 103s 15s/step - loss: 0.0721 - accuracy: 0.9685 - val_loss: 0.7006 - val_accuracy: 0.7600
# Epoch 9/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0880 - accuracy: 0.9775 - val_loss: 0.6873 - val_accuracy: 0.7600
# Epoch 10/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0800 - accuracy: 0.9685 - val_loss: 0.6372 - val_accuracy: 0.7600
# Epoch 11/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0345 - accuracy: 0.9955 - val_loss: 0.5808 - val_accuracy: 0.7600
# Epoch 12/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0628 - accuracy: 0.9820 - val_loss: 0.5435 - val_accuracy: 0.7600
# Epoch 13/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0549 - accuracy: 0.9910 - val_loss: 0.8175 - val_accuracy: 0.8800
# Epoch 14/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0700 - accuracy: 0.9775 - val_loss: 0.6993 - val_accuracy: 0.7600
# Epoch 15/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0632 - accuracy: 0.9865 - val_loss: 0.5821 - val_accuracy: 0.8000
# Epoch 16/50
# 7/7 [==============================] - 107s 16s/step - loss: 0.0657 - accuracy: 0.9730 - val_loss: 0.8698 - val_accuracy: 0.8000
# Epoch 17/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0256 - accuracy: 0.9910 - val_loss: 0.6027 - val_accuracy: 0.7600
# Epoch 18/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0592 - accuracy: 0.9865 - val_loss: 0.7965 - val_accuracy: 0.8800
# Epoch 19/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0555 - accuracy: 0.9820 - val_loss: 0.6314 - val_accuracy: 0.8000
# Epoch 20/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0892 - accuracy: 0.9820 - val_loss: 0.7518 - val_accuracy: 0.7600
# Epoch 21/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0709 - accuracy: 0.9730 - val_loss: 0.9865 - val_accuracy: 0.8000
# Epoch 22/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0315 - accuracy: 0.9955 - val_loss: 0.4522 - val_accuracy: 0.8400
# Epoch 23/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0221 - accuracy: 0.9955 - val_loss: 0.4158 - val_accuracy: 0.8400
# Epoch 24/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0327 - accuracy: 0.9910 - val_loss: 0.5155 - val_accuracy: 0.8400
# Epoch 25/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0502 - accuracy: 0.9865 - val_loss: 0.4944 - val_accuracy: 0.7600
# Epoch 26/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0508 - accuracy: 0.9865 - val_loss: 0.5068 - val_accuracy: 0.8400
# Epoch 27/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0169 - accuracy: 0.9955 - val_loss: 0.5502 - val_accuracy: 0.8400
# Epoch 28/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0581 - accuracy: 0.9820 - val_loss: 0.4837 - val_accuracy: 0.8000
# Epoch 29/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0269 - accuracy: 0.9910 - val_loss: 1.1780 - val_accuracy: 0.6800
# Epoch 30/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0661 - accuracy: 0.9910 - val_loss: 0.3700 - val_accuracy: 0.8000
# Epoch 31/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0606 - accuracy: 0.9820 - val_loss: 0.4372 - val_accuracy: 0.8000
# Epoch 32/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0642 - accuracy: 0.9640 - val_loss: 0.5730 - val_accuracy: 0.8400
# Epoch 33/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0381 - accuracy: 0.9910 - val_loss: 0.8576 - val_accuracy: 0.7600
# Epoch 34/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0449 - accuracy: 0.9865 - val_loss: 0.6777 - val_accuracy: 0.7600
# Epoch 35/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0273 - accuracy: 0.9865 - val_loss: 1.7394 - val_accuracy: 0.6800
# Epoch 36/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0504 - accuracy: 0.9775 - val_loss: 0.8260 - val_accuracy: 0.7600
# Epoch 37/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0376 - accuracy: 0.9775 - val_loss: 0.5458 - val_accuracy: 0.8000
# Epoch 38/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0180 - accuracy: 0.9955 - val_loss: 1.4242 - val_accuracy: 0.6800
# Epoch 39/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0215 - accuracy: 0.9910 - val_loss: 1.4547 - val_accuracy: 0.6800
# Epoch 40/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.8285 - val_accuracy: 0.8800
# Epoch 41/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0566 - accuracy: 0.9910 - val_loss: 1.1539 - val_accuracy: 0.8000
# Epoch 42/50
# 7/7 [==============================] - 107s 15s/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.9249 - val_accuracy: 0.8400
# Epoch 43/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0375 - accuracy: 0.9955 - val_loss: 0.6173 - val_accuracy: 0.7600
# Epoch 44/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.6084 - val_accuracy: 0.8000
# Epoch 45/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.7200
# Epoch 46/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0240 - accuracy: 0.9910 - val_loss: 0.6718 - val_accuracy: 0.7600
# Epoch 47/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0380 - accuracy: 0.9910 - val_loss: 1.0947 - val_accuracy: 0.7600
# Epoch 48/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0239 - accuracy: 0.9955 - val_loss: 1.3025 - val_accuracy: 0.7600
# Epoch 49/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0654 - accuracy: 0.9820 - val_loss: 0.7133 - val_accuracy: 0.8000
# Epoch 50/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.8383 - val_accuracy: 0.8000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 12s 2s/step - loss: 0.3697 - accuracy: 0.9099
# 1/1 [==============================] - 1s 1s/step - loss: 0.8383 - accuracy: 0.8000
# 4
# Epoch 1/50
# 7/7 [==============================] - 119s 14s/step - loss: 0.0735 - accuracy: 0.9820 - val_loss: 0.6843 - val_accuracy: 0.8000
# Epoch 2/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0818 - accuracy: 0.9685 - val_loss: 0.9681 - val_accuracy: 0.8800
# Epoch 3/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0413 - accuracy: 0.9865 - val_loss: 0.9024 - val_accuracy: 0.8400
# Epoch 4/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0645 - accuracy: 0.9820 - val_loss: 0.6555 - val_accuracy: 0.8000
# Epoch 5/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0505 - accuracy: 0.9865 - val_loss: 0.7186 - val_accuracy: 0.8000
# Epoch 6/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0614 - accuracy: 0.9910 - val_loss: 0.9436 - val_accuracy: 0.7600
# Epoch 7/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0284 - accuracy: 0.9955 - val_loss: 0.7212 - val_accuracy: 0.8000
# Epoch 8/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0755 - accuracy: 0.9820 - val_loss: 0.8631 - val_accuracy: 0.8000
# Epoch 9/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0534 - accuracy: 0.9910 - val_loss: 0.9066 - val_accuracy: 0.8000
# Epoch 10/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.1451 - val_accuracy: 0.7600
# Epoch 11/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0406 - accuracy: 0.9955 - val_loss: 1.4093 - val_accuracy: 0.8000
# Epoch 12/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0530 - accuracy: 0.9865 - val_loss: 0.8407 - val_accuracy: 0.7200
# Epoch 13/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0371 - accuracy: 0.9820 - val_loss: 0.7740 - val_accuracy: 0.7200
# Epoch 14/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0334 - accuracy: 0.9865 - val_loss: 0.7446 - val_accuracy: 0.8400
# Epoch 15/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0258 - accuracy: 0.9955 - val_loss: 0.5126 - val_accuracy: 0.8000
# Epoch 16/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0272 - accuracy: 0.9955 - val_loss: 0.6188 - val_accuracy: 0.7600
# Epoch 17/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0656 - accuracy: 0.9910 - val_loss: 1.1829 - val_accuracy: 0.8000
# Epoch 18/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.3233 - val_accuracy: 0.8000
# Epoch 19/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0215 - accuracy: 0.9910 - val_loss: 1.0433 - val_accuracy: 0.8000
# Epoch 20/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0365 - accuracy: 0.9865 - val_loss: 0.9208 - val_accuracy: 0.8000
# Epoch 21/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.8665 - val_accuracy: 0.7600
# Epoch 22/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0241 - accuracy: 0.9910 - val_loss: 0.7896 - val_accuracy: 0.8000
# Epoch 23/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0376 - accuracy: 0.9955 - val_loss: 0.5318 - val_accuracy: 0.8400
# Epoch 24/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0305 - accuracy: 0.9910 - val_loss: 0.8890 - val_accuracy: 0.8400
# Epoch 25/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3166 - val_accuracy: 0.7200
# Epoch 26/50
# 7/7 [==============================] - 105s 15s/step - loss: 0.0199 - accuracy: 0.9955 - val_loss: 1.3550 - val_accuracy: 0.7200
# Epoch 27/50
# 7/7 [==============================] - 100s 14s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.8193 - val_accuracy: 0.7200
# Epoch 28/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0214 - accuracy: 0.9955 - val_loss: 1.5094 - val_accuracy: 0.7600
# Epoch 29/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.2773 - val_accuracy: 0.7200
# Epoch 30/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.0387 - val_accuracy: 0.7600
# Epoch 31/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.9843 - val_accuracy: 0.7600
# Epoch 32/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.1290 - val_accuracy: 0.7600
# Epoch 33/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0155 - accuracy: 0.9910 - val_loss: 1.4014 - val_accuracy: 0.7200
# Epoch 34/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.3865 - val_accuracy: 0.7200
# Epoch 35/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 1.6484 - val_accuracy: 0.7200
# Epoch 36/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.5216 - val_accuracy: 0.7200
# Epoch 37/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0477 - accuracy: 0.9910 - val_loss: 1.4841 - val_accuracy: 0.7600
# Epoch 38/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 1.6289 - val_accuracy: 0.7600
# Epoch 39/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0207 - accuracy: 0.9910 - val_loss: 1.6170 - val_accuracy: 0.8400
# Epoch 40/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0332 - accuracy: 0.9910 - val_loss: 1.2129 - val_accuracy: 0.8000
# Epoch 41/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0390 - accuracy: 0.9955 - val_loss: 1.3809 - val_accuracy: 0.8000
# Epoch 42/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0244 - accuracy: 0.9910 - val_loss: 1.2660 - val_accuracy: 0.8400
# Epoch 43/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0244 - accuracy: 0.9955 - val_loss: 1.1504 - val_accuracy: 0.7600
# Epoch 44/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.2077 - val_accuracy: 0.8400
# Epoch 45/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 1.1233 - val_accuracy: 0.8400
# Epoch 46/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 1.2737 - val_accuracy: 0.8400
# Epoch 47/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0114 - accuracy: 0.9955 - val_loss: 1.5973 - val_accuracy: 0.7200
# Epoch 48/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.5188 - val_accuracy: 0.7200
# Epoch 49/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 1.4019 - val_accuracy: 0.7200
# Epoch 50/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 1.4949 - val_accuracy: 0.7600
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 11s 1s/step - loss: 0.4459 - accuracy: 0.9009
# 1/1 [==============================] - 1s 1s/step - loss: 1.4949 - accuracy: 0.7600
# 5
# Epoch 1/50
# 7/7 [==============================] - 117s 14s/step - loss: 0.0390 - accuracy: 0.9865 - val_loss: 0.6802 - val_accuracy: 0.8800
# Epoch 2/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0257 - accuracy: 0.9955 - val_loss: 0.7580 - val_accuracy: 0.8800
# Epoch 3/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0253 - accuracy: 0.9955 - val_loss: 0.7467 - val_accuracy: 0.8800
# Epoch 4/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.9701 - val_accuracy: 0.8800
# Epoch 5/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0171 - accuracy: 0.9955 - val_loss: 0.6074 - val_accuracy: 0.9600
# Epoch 6/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0400 - accuracy: 0.9955 - val_loss: 0.5778 - val_accuracy: 0.9600
# Epoch 7/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5135 - val_accuracy: 0.9600
# Epoch 8/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.4326 - val_accuracy: 0.9600
# Epoch 9/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0917 - accuracy: 0.9685 - val_loss: 0.3150 - val_accuracy: 0.9600
# Epoch 10/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0354 - accuracy: 0.9955 - val_loss: 0.5538 - val_accuracy: 0.8800
# Epoch 11/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.4836 - val_accuracy: 0.9200
# Epoch 12/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.3601 - val_accuracy: 0.9600
# Epoch 13/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0212 - accuracy: 0.9955 - val_loss: 0.3602 - val_accuracy: 0.9200
# Epoch 14/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4792 - val_accuracy: 0.8800
# Epoch 15/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0468 - accuracy: 0.9775 - val_loss: 0.1465 - val_accuracy: 0.9600
# Epoch 16/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0220 - accuracy: 0.9955 - val_loss: 0.3416 - val_accuracy: 0.8400
# Epoch 17/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0364 - accuracy: 0.9955 - val_loss: 0.6943 - val_accuracy: 0.8400
# Epoch 18/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7726 - val_accuracy: 0.8400
# Epoch 19/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0223 - accuracy: 0.9955 - val_loss: 0.7239 - val_accuracy: 0.7600
# Epoch 20/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0201 - accuracy: 0.9955 - val_loss: 0.3654 - val_accuracy: 0.9200
# Epoch 21/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.9600
# Epoch 22/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.4877 - val_accuracy: 0.9600
# Epoch 23/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0317 - accuracy: 0.9955 - val_loss: 0.4982 - val_accuracy: 0.8400
# Epoch 24/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0305 - accuracy: 0.9910 - val_loss: 0.4514 - val_accuracy: 0.8400
# Epoch 25/50
# 7/7 [==============================] - 100s 14s/step - loss: 0.0493 - accuracy: 0.9865 - val_loss: 0.6402 - val_accuracy: 0.8800
# Epoch 26/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0278 - accuracy: 0.9865 - val_loss: 0.4126 - val_accuracy: 0.8800
# Epoch 27/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0161 - accuracy: 0.9955 - val_loss: 0.9429 - val_accuracy: 0.8000
# Epoch 28/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0817 - accuracy: 0.9820 - val_loss: 0.2123 - val_accuracy: 0.9200
# Epoch 29/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 0.1392 - val_accuracy: 0.9600
# Epoch 30/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0101 - accuracy: 0.9955 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 31/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0492 - accuracy: 0.9865 - val_loss: 0.1430 - val_accuracy: 0.9600
# Epoch 32/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4944 - val_accuracy: 0.9200
# Epoch 33/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0282 - accuracy: 0.9955 - val_loss: 0.3820 - val_accuracy: 0.9600
# Epoch 34/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 0.9600
# Epoch 35/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9600
# Epoch 36/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9600
# Epoch 37/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0213 - accuracy: 0.9955 - val_loss: 0.0651 - val_accuracy: 0.9600
# Epoch 38/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.9200
# Epoch 39/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0691 - accuracy: 0.9820 - val_loss: 0.1618 - val_accuracy: 0.9200
# Epoch 40/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.1347 - val_accuracy: 0.9600
# Epoch 41/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0158 - accuracy: 0.9955 - val_loss: 0.1741 - val_accuracy: 0.9600
# Epoch 42/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0408 - accuracy: 0.9865 - val_loss: 0.1483 - val_accuracy: 0.9200
# Epoch 43/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.3848 - val_accuracy: 0.9200
# Epoch 44/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0094 - accuracy: 0.9955 - val_loss: 0.5292 - val_accuracy: 0.9200
# Epoch 45/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0470 - accuracy: 0.9910 - val_loss: 0.1776 - val_accuracy: 0.9200
# Epoch 46/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 0.0952 - val_accuracy: 0.9600
# Epoch 47/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.2070 - val_accuracy: 0.9200
# Epoch 48/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 49/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0573 - accuracy: 0.9910 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 50/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.3598 - val_accuracy: 0.9200
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 10s 1s/step - loss: 0.4471 - accuracy: 0.9189
# 1/1 [==============================] - 1s 1s/step - loss: 0.3598 - accuracy: 0.9200
# 6
# Epoch 1/50
# 7/7 [==============================] - 121s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 0.9600
# Epoch 2/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2180 - val_accuracy: 0.9200
# Epoch 3/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9600
# Epoch 4/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.2139 - val_accuracy: 0.9200
# Epoch 5/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0117 - accuracy: 0.9955 - val_loss: 0.2134 - val_accuracy: 0.8800
# Epoch 6/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9200
# Epoch 7/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9600
# Epoch 8/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0237 - accuracy: 0.9910 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 9/50
# 7/7 [==============================] - 94s 13s/step - loss: 7.2399e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 10/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9200
# Epoch 11/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.8400
# Epoch 12/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0150 - accuracy: 0.9955 - val_loss: 0.0799 - val_accuracy: 0.9600
# Epoch 13/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0494 - accuracy: 0.9910 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 14/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 15/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 16/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 17/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 18/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 19/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0928 - val_accuracy: 0.9600
# Epoch 20/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0096 - accuracy: 0.9955 - val_loss: 0.1074 - val_accuracy: 0.9600
# Epoch 21/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0685 - accuracy: 0.9865 - val_loss: 0.1398 - val_accuracy: 0.9600
# Epoch 22/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.1567 - accuracy: 0.9595 - val_loss: 0.8176 - val_accuracy: 0.9200
# Epoch 23/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0962 - accuracy: 0.9685 - val_loss: 0.1045 - val_accuracy: 1.0000
# Epoch 24/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0392 - accuracy: 0.9865 - val_loss: 0.1753 - val_accuracy: 0.9600
# Epoch 25/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0466 - accuracy: 0.9955 - val_loss: 0.2974 - val_accuracy: 0.9200
# Epoch 26/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0403 - accuracy: 0.9910 - val_loss: 0.2723 - val_accuracy: 0.9200
# Epoch 27/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0653 - accuracy: 0.9820 - val_loss: 0.3518 - val_accuracy: 0.9600
# Epoch 28/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.3276 - val_accuracy: 0.9200
# Epoch 29/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0378 - accuracy: 0.9910 - val_loss: 0.3203 - val_accuracy: 0.9200
# Epoch 30/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2984 - val_accuracy: 1.0000
# Epoch 31/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0520 - accuracy: 0.9910 - val_loss: 0.6016 - val_accuracy: 0.9200
# Epoch 32/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.7782 - val_accuracy: 0.9200
# Epoch 33/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.4663 - val_accuracy: 0.9200
# Epoch 34/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.5146 - val_accuracy: 0.9200
# Epoch 35/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0413 - accuracy: 0.9910 - val_loss: 1.2675 - val_accuracy: 0.8800
# Epoch 36/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.7994 - val_accuracy: 0.8800
# Epoch 37/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0070 - accuracy: 0.9955 - val_loss: 0.7819 - val_accuracy: 0.8800
# Epoch 38/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.8800
# Epoch 39/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0058 - accuracy: 0.9955 - val_loss: 0.8648 - val_accuracy: 0.8800
# Epoch 40/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0092 - accuracy: 0.9955 - val_loss: 0.4151 - val_accuracy: 0.9200
# Epoch 41/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.3524 - val_accuracy: 0.9200
# Epoch 42/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4892 - val_accuracy: 0.9200
# Epoch 43/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0206 - accuracy: 0.9910 - val_loss: 0.1829 - val_accuracy: 0.9600
# Epoch 44/50
# 7/7 [==============================] - 96s 14s/step - loss: 9.2400e-04 - accuracy: 1.0000 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 45/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0563 - accuracy: 0.9910 - val_loss: 0.2833 - val_accuracy: 0.9200
# Epoch 46/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0298 - accuracy: 0.9955 - val_loss: 0.3255 - val_accuracy: 0.8800
# Epoch 47/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.3546 - val_accuracy: 0.9600
# Epoch 48/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0237 - accuracy: 0.9910 - val_loss: 0.3678 - val_accuracy: 0.9600
# Epoch 49/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.7173 - val_accuracy: 0.8800
# Epoch 50/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0292 - accuracy: 0.9955 - val_loss: 0.4685 - val_accuracy: 0.9200
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 11s 1s/step - loss: 0.5212 - accuracy: 0.9189
# 1/1 [==============================] - 1s 1s/step - loss: 0.4685 - accuracy: 0.9200
# 7
# Epoch 1/50
# 7/7 [==============================] - 155s 15s/step - loss: 0.0111 - accuracy: 0.9955 - val_loss: 0.3488 - val_accuracy: 0.8400
# Epoch 2/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0363 - accuracy: 0.9910 - val_loss: 0.3061 - val_accuracy: 0.8800
# Epoch 3/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4942 - val_accuracy: 0.8400
# Epoch 4/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0347 - accuracy: 0.9865 - val_loss: 0.3595 - val_accuracy: 0.8400
# Epoch 5/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0188 - accuracy: 0.9955 - val_loss: 0.2427 - val_accuracy: 0.9200
# Epoch 6/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 1.0000
# Epoch 7/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3576 - val_accuracy: 1.0000
# Epoch 8/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.9600
# Epoch 9/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0430 - accuracy: 0.9865 - val_loss: 0.2535 - val_accuracy: 0.9600
# Epoch 10/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0195 - accuracy: 0.9955 - val_loss: 0.3758 - val_accuracy: 0.9200
# Epoch 11/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0489 - accuracy: 0.9865 - val_loss: 0.2899 - val_accuracy: 0.9200
# Epoch 12/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.3836 - val_accuracy: 0.9200
# Epoch 13/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.9018 - val_accuracy: 0.8400
# Epoch 14/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0084 - accuracy: 0.9955 - val_loss: 0.7286 - val_accuracy: 0.8800
# Epoch 15/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0217 - accuracy: 0.9910 - val_loss: 0.5440 - val_accuracy: 0.8800
# Epoch 16/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0360 - accuracy: 0.9865 - val_loss: 0.4114 - val_accuracy: 0.8800
# Epoch 17/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.9251 - val_accuracy: 0.8400
# Epoch 18/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 1.3707 - val_accuracy: 0.8000
# Epoch 19/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0355 - accuracy: 0.9955 - val_loss: 2.9072 - val_accuracy: 0.6800
# Epoch 20/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0435 - accuracy: 0.9955 - val_loss: 1.8934 - val_accuracy: 0.8000
# Epoch 21/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0395 - accuracy: 0.9865 - val_loss: 0.5380 - val_accuracy: 0.8800
# Epoch 22/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.8927 - val_accuracy: 0.8400
# Epoch 23/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4006 - val_accuracy: 0.9200
# Epoch 24/50
# ...
# Epoch 43/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9583
# Epoch 44/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.7162 - val_accuracy: 0.9167
# Epoch 45/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0242 - accuracy: 0.9910 - val_loss: 0.5023 - val_accuracy: 0.9583
# Epoch 46/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0219 - accuracy: 0.9910 - val_loss: 0.6639 - val_accuracy: 0.9583
# Epoch 47/50
# 7/7 [==============================] - 95s 14s/step - loss: 2.7907e-04 - accuracy: 1.0000 - val_loss: 1.9914 - val_accuracy: 0.7083
# Epoch 48/50
# 7/7 [==============================] - 94s 14s/step - loss: 9.3979e-04 - accuracy: 1.0000 - val_loss: 2.5309 - val_accuracy: 0.7083
# Epoch 49/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.7986 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0283 - accuracy: 0.9910 - val_loss: 1.3356 - val_accuracy: 0.7917
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 12s 2s/step - loss: 0.5175 - accuracy: 0.9058
# 1/1 [==============================] - 1s 1s/step - loss: 1.3356 - accuracy: 0.7917
# 9
# Epoch 1/50
# 7/7 [==============================] - 112s 14s/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.9583
# Epoch 2/50
# 7/7 [==============================] - 91s 13s/step - loss: 0.0296 - accuracy: 0.9910 - val_loss: 1.7007 - val_accuracy: 0.7083
# Epoch 3/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0440 - accuracy: 0.9955 - val_loss: 1.2437 - val_accuracy: 0.8750
# Epoch 4/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0197 - accuracy: 0.9910 - val_loss: 0.2083 - val_accuracy: 0.9583
# Epoch 5/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0259 - accuracy: 0.9910 - val_loss: 0.2184 - val_accuracy: 0.9167
# Epoch 6/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0348 - accuracy: 0.9955 - val_loss: 0.5807 - val_accuracy: 0.9583
# Epoch 7/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4046 - val_accuracy: 0.9583
# Epoch 8/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0288 - accuracy: 0.9955 - val_loss: 0.4105 - val_accuracy: 0.9583
# Epoch 9/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.7076 - val_accuracy: 0.8750
# Epoch 10/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5526 - val_accuracy: 0.9583
# Epoch 11/50
# 7/7 [==============================] - 92s 13s/step - loss: 8.4051e-05 - accuracy: 1.0000 - val_loss: 0.6183 - val_accuracy: 0.9167
# Epoch 12/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0378 - accuracy: 0.9955 - val_loss: 0.5648 - val_accuracy: 0.9167
# Epoch 13/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4057 - val_accuracy: 0.9167
# Epoch 14/50
# 7/7 [==============================] - 92s 13s/step - loss: 0.0263 - accuracy: 0.9955 - val_loss: 0.4921 - val_accuracy: 0.9167
# Epoch 15/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7398 - val_accuracy: 0.8750
# Epoch 16/50
# 7/7 [==============================] - 93s 13s/step - loss: 0.0158 - accuracy: 0.9955 - val_loss: 0.6791 - val_accuracy: 0.9167
# Epoch 17/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7966 - val_accuracy: 0.9583
# Epoch 18/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0438 - accuracy: 0.9955 - val_loss: 1.0808 - val_accuracy: 0.8750
# Epoch 19/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0193 - accuracy: 0.9910 - val_loss: 1.0985 - val_accuracy: 0.8750
# Epoch 20/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.6085 - val_accuracy: 0.9167
# Epoch 21/50
# 7/7 [==============================] - 99s 14s/step - loss: 8.2916e-04 - accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.9167
# Epoch 22/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.7497 - val_accuracy: 0.8333
# Epoch 23/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.0934 - val_accuracy: 0.8333
# Epoch 24/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.6414 - val_accuracy: 0.8333
# Epoch 25/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0290 - accuracy: 0.9955 - val_loss: 0.9930 - val_accuracy: 0.7917
# Epoch 26/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.5106 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 2.1027 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.6147 - val_accuracy: 0.8333
# Epoch 29/50
# 7/7 [==============================] - 100s 14s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0631 - val_accuracy: 0.8333
# Epoch 30/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.9558 - val_accuracy: 0.8333
# Epoch 31/50
# 7/7 [==============================] - 99s 14s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.6872 - val_accuracy: 0.8750
# Epoch 32/50
# 7/7 [==============================] - 105s 15s/step - loss: 4.4996e-05 - accuracy: 1.0000 - val_loss: 0.4826 - val_accuracy: 0.9583
# Epoch 33/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0178 - accuracy: 0.9955 - val_loss: 0.5358 - val_accuracy: 0.9583
# Epoch 34/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3654 - val_accuracy: 0.9167
# Epoch 35/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0278 - accuracy: 0.9955 - val_loss: 0.4667 - val_accuracy: 0.9583
# Epoch 36/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.9583
# Epoch 37/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.9583
# Epoch 38/50
# 7/7 [==============================] - 95s 13s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5132 - val_accuracy: 0.9583
# Epoch 39/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.4595 - val_accuracy: 0.9583
# Epoch 40/50
# 7/7 [==============================] - 100s 14s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3428 - val_accuracy: 0.9583
# Epoch 41/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0365 - accuracy: 0.9955 - val_loss: 0.6760 - val_accuracy: 0.8750
# Epoch 42/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3676 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9703 - val_accuracy: 0.9167
# Epoch 44/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0306 - accuracy: 0.9910 - val_loss: 0.5311 - val_accuracy: 0.9167
# Epoch 45/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.9583
# Epoch 46/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 0.9583
# Epoch 47/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2768 - val_accuracy: 0.9167
# Epoch 48/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0297 - accuracy: 0.9955 - val_loss: 0.1470 - val_accuracy: 0.9583
# Epoch 49/50
# 7/7 [==============================] - 94s 14s/step - loss: 5.6611e-04 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9583
# Epoch 50/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9583
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 11s 1s/step - loss: 0.2247 - accuracy: 0.9507
# 1/1 [==============================] - 1s 1s/step - loss: 0.2220 - accuracy: 0.9583
# 10
# Epoch 1/50
# 7/7 [==============================] - 125s 14s/step - loss: 6.1453e-04 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 2/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 3/50
# 7/7 [==============================] - 95s 14s/step - loss: 1.2627e-04 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 1.0000
# Epoch 4/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0497 - accuracy: 0.9955 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 5/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9583
# Epoch 6/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 7/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 8/50
# 7/7 [==============================] - 94s 14s/step - loss: 0.0419 - accuracy: 0.9910 - val_loss: 0.1661 - val_accuracy: 0.8750
# Epoch 9/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0157 - accuracy: 0.9955 - val_loss: 0.6184 - val_accuracy: 0.8750
# Epoch 10/50
# 7/7 [==============================] - 97s 14s/step - loss: 0.0705 - accuracy: 0.9865 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 11/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.4898 - val_accuracy: 0.8750
# Epoch 12/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0325 - accuracy: 0.9910 - val_loss: 0.1110 - val_accuracy: 0.9583
# Epoch 13/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1044 - val_accuracy: 0.9583
# Epoch 14/50
# 7/7 [==============================] - 94s 13s/step - loss: 2.2260e-04 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9583
# Epoch 15/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3045 - val_accuracy: 0.9583
# Epoch 16/50
# 7/7 [==============================] - 100s 14s/step - loss: 7.5298e-04 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9167
# Epoch 17/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0054 - accuracy: 0.9955 - val_loss: 0.2131 - val_accuracy: 0.9583
# Epoch 18/50
# 7/7 [==============================] - 96s 14s/step - loss: 1.3434e-04 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9583
# Epoch 19/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 20/50
# 7/7 [==============================] - 99s 14s/step - loss: 2.6123e-04 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 21/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 22/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9584 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.6353 - val_accuracy: 0.7917
# Epoch 24/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 1.0190 - val_accuracy: 0.8333
# Epoch 25/50
# 7/7 [==============================] - 94s 13s/step - loss: 8.5237e-04 - accuracy: 1.0000 - val_loss: 0.9725 - val_accuracy: 0.8750
# Epoch 26/50
# 7/7 [==============================] - 95s 14s/step - loss: 5.6345e-04 - accuracy: 1.0000 - val_loss: 1.0732 - val_accuracy: 0.8333
# Epoch 27/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.9193 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 111s 16s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.4637 - val_accuracy: 0.7917
# Epoch 29/50
# 7/7 [==============================] - 98s 14s/step - loss: 2.5141e-04 - accuracy: 1.0000 - val_loss: 2.5537 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 99s 14s/step - loss: 3.5973e-05 - accuracy: 1.0000 - val_loss: 2.6192 - val_accuracy: 0.7917
# Epoch 31/50
# 7/7 [==============================] - 98s 14s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.6294 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 95s 14s/step - loss: 3.2088e-04 - accuracy: 1.0000 - val_loss: 1.2826 - val_accuracy: 0.7917
# Epoch 33/50
# 7/7 [==============================] - 95s 14s/step - loss: 3.8263e-04 - accuracy: 1.0000 - val_loss: 1.2980 - val_accuracy: 0.8333
# Epoch 34/50
# 7/7 [==============================] - 120s 18s/step - loss: 4.5932e-04 - accuracy: 1.0000 - val_loss: 1.3181 - val_accuracy: 0.8333
# Epoch 35/50
# 7/7 [==============================] - 98s 14s/step - loss: 6.7948e-04 - accuracy: 1.0000 - val_loss: 1.4595 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 98s 14s/step - loss: 9.7282e-04 - accuracy: 1.0000 - val_loss: 1.7703 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 99s 14s/step - loss: 2.4424e-04 - accuracy: 1.0000 - val_loss: 2.3019 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 97s 14s/step - loss: 5.5909e-05 - accuracy: 1.0000 - val_loss: 2.5566 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 95s 14s/step - loss: 3.1391e-05 - accuracy: 1.0000 - val_loss: 2.6706 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 95s 14s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.3499 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 97s 14s/step - loss: 3.2361e-05 - accuracy: 1.0000 - val_loss: 1.6358 - val_accuracy: 0.8333
# Epoch 42/50
# 7/7 [==============================] - 98s 14s/step - loss: 1.5670e-04 - accuracy: 1.0000 - val_loss: 1.3821 - val_accuracy: 0.8333
# Epoch 43/50
# 7/7 [==============================] - 95s 14s/step - loss: 1.0141e-04 - accuracy: 1.0000 - val_loss: 1.3119 - val_accuracy: 0.8750
# Epoch 44/50
# 7/7 [==============================] - 95s 14s/step - loss: 5.9252e-04 - accuracy: 1.0000 - val_loss: 1.3628 - val_accuracy: 0.8333
# Epoch 45/50
# 7/7 [==============================] - 95s 14s/step - loss: 3.3838e-05 - accuracy: 1.0000 - val_loss: 1.4508 - val_accuracy: 0.8333
# Epoch 46/50
# 7/7 [==============================] - 94s 13s/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 1.7227 - val_accuracy: 0.8333
# Epoch 47/50
# 7/7 [==============================] - 96s 14s/step - loss: 2.8993e-05 - accuracy: 1.0000 - val_loss: 2.4097 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 95s 14s/step - loss: 1.1661e-05 - accuracy: 1.0000 - val_loss: 2.8045 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 97s 14s/step - loss: 1.6522e-04 - accuracy: 1.0000 - val_loss: 2.9617 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - 96s 14s/step - loss: 0.0058 - accuracy: 0.9955 - val_loss: 3.6669 - val_accuracy: 0.7083
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 7/7 [==============================] - 11s 2s/step - loss: 2.9351 - accuracy: 0.7175
# 1/1 [==============================] - 1s 1s/step - loss: 3.6669 - accuracy: 0.7083

# %%
i
# Out:
# 9

# %%
scipy.io.savemat('cancer_NC_output/total_accuracy_tr.mat', mdict={'total_accuracy_tr': total_accuracy_tr})
scipy.io.savemat('cancer_NC_output/total_accuracy_te.mat', mdict={'total_accuracy_te': total_accuracy_te})


scipy.io.savemat('cancer_NC_output/total_confusion_matrix_1_last.mat', mdict={'total_confusion_matrix_1_last': total_confusion_matrix_1_last})

scipy.io.savemat('cancer_NC_output/mean_fpr_t.mat', mdict={'mean_fpr_t': mean_fpr_t})
scipy.io.savemat('cancer_NC_output/mean_tpr_t.mat', mdict={'mean_tpr_t': mean_tpr_t})
scipy.io.savemat('cancer_NC_output/mean_auc_t.mat', mdict={'mean_auc_t': mean_auc_t})
